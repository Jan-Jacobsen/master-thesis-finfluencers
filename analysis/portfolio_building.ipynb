# %% [markdown]
# ### Data Loading

# %%
import pandas as pd
import portfolio_utils as pfu
import itertools
import json
import time
import os

# %%
# load extraction results
extractions_df = pd.read_csv("../data/matched/VIDEOS_inf_llama3_ft_v4_q8_0_llamacpp_guided.csv", sep=";")
# load metadata df to get upload dates and channel ids
metadata_df = pd.read_csv("../data/yt_metadata/video_metadata.csv", sep=";")[["video_id", "upload_date", "uploader_id"]].rename(columns={"uploader_id": "channel_id"})
# join metadata to extractions
extractions_df = extractions_df.merge(metadata_df, on="video_id")
trade_info_col = "trade_info_no_neutrals"
extractions_df = extractions_df[["video_id", "upload_date", "channel_id", trade_info_col]]
extractions_df.rename(columns={trade_info_col: "trade_info"}, inplace=True)

# load returns dfs
returns_path = "../data/asset_data/returns"
returns_dfs = {"stock": pd.read_csv(f"{returns_path}/stocks_returns.csv", sep=";"),
               "etf": pd.read_csv(f"{returns_path}/etfs_returns.csv", sep=";"),
                "crypto": pd.read_csv(f"{returns_path}/cryptos_returns.csv", sep=";"),
                "commodity": pd.read_csv(f"{returns_path}/commodities_returns.csv", sep=";"),
                "benchmark": pd.read_csv(f"{returns_path}/benchmarks_returns.csv", sep=";")
}

# join returns dfs, add asset type to column names, set date column as index
colname_sep = "+" # separator for asset type and ticker in column names
for asset_type in returns_dfs.keys():
    # make date col index
    returns_dfs[asset_type].set_index("date", inplace=True)
    # rename columns
    returns_dfs[asset_type].columns = [f"{asset_type}{colname_sep}{col}" for col in returns_dfs[asset_type].columns]
    print(f"{asset_type} returns df shape: {returns_dfs[asset_type].shape}")

returns_df = pd.concat(returns_dfs.values(), axis=1)
print(f"returns_df shape after joining: {returns_df.shape}")
# make sure we didn't lose any dates
assert returns_df.index.equals(returns_dfs["stock"].index)
del returns_dfs

# instantiate portfolio builder (with default settings for now)
pb = pfu.PortfolioBuilder(extractions_df=extractions_df, 
                          returns_df=returns_df, 
                          settings=None,
                          ticker_sep=colname_sep)
# Out:
# stock returns df shape: (2012, 10947)
# etf returns df shape: (2012, 3182)
# crypto returns df shape: (2012, 4576)
# commodity returns df shape: (2012, 26)
# benchmark returns df shape: (2012, 6)
# returns_df shape after joining: (2012, 18737)
# PortfolioBuilder: Initialized with 45967 videos from 231 unique channels.
# PortfolioBuilder: Only considering videos with non-empty trade_info: 16510 videos from 213 unique channels.

# %% [markdown]
# ### Portfolio Computation
#
# We compute and save portfolios for each channel.
# We go through multiple runs to obtain several portfolio versions, each with a different combination of settings (i.e. max holding period, neutral asset, etc.)

# %%
save_dir = "../data/portfolios/raw"

pf_types = ["equal_weight"]
neutral_assets = ["cash", "3m_tbills", "SPY"] # cash, 3m-tbills (-> risk-free asset), S&P 500 ETF
#neutral_assets = ["SPY"] # cash only for now
max_holding_periods = [21, 126, 252, 99999] # 1 month, 6 months, 1 year, no limit
#max_holding_periods = [252]
after_upload_waits = [1] # 1 day
max_positions = [5, 99999] # max 5, no limit
#max_positions = [99999] # no limit

# save parameter choices to save dir (json)
with open(f"{save_dir}/parameter_choices.json", "w") as f:
    json.dump({"pf_types": pf_types, "neutral_assets": neutral_assets, "max_holding_periods": max_holding_periods, "after_upload_waits": after_upload_waits, "max_positions": max_positions}, f)

# save unique channel_id list to save dir (might be useful for reloading portfolio data later)
pd.Series(pb.ext["channel_id"].unique()).rename("channel_ids").to_csv(f"{save_dir}/channel_ids.csv", sep=";", index=False)

# iterate over portfolio parameter combinations
for pf_type, neutral_asset, max_hp, after_upload_waits, max_pos in itertools.product(pf_types, neutral_assets, max_holding_periods, after_upload_waits, max_positions):
    start_time = time.time()

    # create output dir for the run 
    run_name = f"{pf_type}_{neutral_asset}_hp{max_hp}_wait{after_upload_waits}_pos{max_pos}"
    run_save_dir = f"{save_dir}/{run_name}"
    if not os.path.exists(run_save_dir):
        os.makedirs(run_save_dir)
    else:
        print(f"Run dir {run_save_dir} already exists. Skipping.")
        continue

    # define settings for portfolio builder
    # note: we compute all portfolios for the full observation range. We can later still choose to only consider the active trading period for each portfolio for computing performance measures. 
    portfolio_settings = {#"pf_start_date": "2016-01-04", # default values for observation period, kept constant
                            #  "pf_end_date": "2023-12-29",
                            "pf_initial_value": 1, 
                            "portfolio_type": pf_type, 
                            "max_positions": max_pos, # max number of non-cash positions in a portfolio (sell oldest positions if exceeded)
                            "max_holding_period": max_hp, # max number of trading days to hold a position (sell if exceeded)
                            "neutral_asset": neutral_asset, # asset to hold in place of cash        
                            "min_days_wait_after_upload": 1, # minimum number of days to wait after upload before trading
                    }
    print(f"{30*'-'}\nStarting run: {run_name}")
    # update settings for portfolio builder (without having to reload returns and extraction data)
    pb.update_settings(new_settings=portfolio_settings)

    # save run settings to run dir
    with open(f"{run_save_dir}/settings.json", "w") as f:
        json.dump(portfolio_settings, f)

    # build portfolios for all channel ids and save results
    for i, channel_id in enumerate(pb.ext["channel_id"].unique()):
        pos_df_bt, pos_df_at, trade_logs_df = pb.compute_portfolio(channel_id=channel_id, debug=False)
        # save results
        pos_df_bt.to_csv(f"{run_save_dir}/{channel_id}_pos_bt.csv", sep=";", index=True)
        pos_df_at.to_csv(f"{run_save_dir}/{channel_id}_pos_at.csv", sep=";", index=True)
        trade_logs_df.to_csv(f"{run_save_dir}/{channel_id}_trade_logs.csv", sep=";", index=False)
        if (i+1) % 20 == 0:
            print(f"  - Processed {i+1}/{len(pb.ext['channel_id'].unique())} channel ids in {time.time()-start_time:.2f}s")
    print(f"Run {pf_type}_{neutral_asset}_hp{max_hp}_wait{after_upload_waits}_pos{max_pos} completed in {time.time()-start_time:.2f}s")
# Out:
# Run dir ../data/portfolios/raw/equal_weight_cash_hp21_wait1_pos5 already exists. Skipping.
# ------------------------------
# Starting run: equal_weight_cash_hp21_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 43.30s
#   - Processed 40/213 channel ids in 93.46s
#   - Processed 60/213 channel ids in 137.45s
#   - Processed 80/213 channel ids in 174.78s
#   - Processed 100/213 channel ids in 211.88s
#   - Processed 120/213 channel ids in 243.44s
#   - Processed 140/213 channel ids in 274.08s
#   - Processed 160/213 channel ids in 304.75s
#   - Processed 180/213 channel ids in 334.46s
#   - Processed 200/213 channel ids in 363.95s
# Run equal_weight_cash_hp21_wait1_pos99999 completed in 382.63s
# ------------------------------
# Starting run: equal_weight_cash_hp126_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 48.38s
#   - Processed 40/213 channel ids in 99.94s
#   - Processed 60/213 channel ids in 142.39s
#   - Processed 80/213 channel ids in 179.46s
#   - Processed 100/213 channel ids in 219.71s
#   - Processed 120/213 channel ids in 253.57s
#   - Processed 140/213 channel ids in 286.64s
#   - Processed 160/213 channel ids in 319.22s
#   - Processed 180/213 channel ids in 350.54s
#   - Processed 200/213 channel ids in 382.28s
# Run equal_weight_cash_hp126_wait1_pos5 completed in 401.82s
# ------------------------------
# Starting run: equal_weight_cash_hp126_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 49.29s
#   - Processed 40/213 channel ids in 100.53s
#   - Processed 60/213 channel ids in 143.75s
#   - Processed 80/213 channel ids in 181.56s
#   - Processed 100/213 channel ids in 222.97s
#   - Processed 120/213 channel ids in 256.89s
#   - Processed 140/213 channel ids in 289.61s
#   - Processed 160/213 channel ids in 321.29s
#   - Processed 180/213 channel ids in 352.25s
#   - Processed 200/213 channel ids in 383.33s
# Run equal_weight_cash_hp126_wait1_pos99999 completed in 402.60s
# ------------------------------
# Starting run: equal_weight_cash_hp252_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 44.87s
#   - Processed 40/213 channel ids in 93.61s
#   - Processed 60/213 channel ids in 135.54s
#   - Processed 80/213 channel ids in 172.38s
#   - Processed 100/213 channel ids in 213.04s
#   - Processed 120/213 channel ids in 247.21s
#   - Processed 140/213 channel ids in 280.11s
#   - Processed 160/213 channel ids in 312.53s
#   - Processed 180/213 channel ids in 343.59s
#   - Processed 200/213 channel ids in 374.52s
# Run equal_weight_cash_hp252_wait1_pos5 completed in 394.16s
# Run dir ../data/portfolios/raw/equal_weight_cash_hp252_wait1_pos99999 already exists. Skipping.
# ------------------------------
# Starting run: equal_weight_cash_hp99999_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 47.03s
#   - Processed 40/213 channel ids in 96.60s
#   - Processed 60/213 channel ids in 139.68s
#   - Processed 80/213 channel ids in 177.53s
#   - Processed 100/213 channel ids in 218.12s
#   - Processed 120/213 channel ids in 252.01s
#   - Processed 140/213 channel ids in 289.71s
#   - Processed 160/213 channel ids in 322.10s
#   - Processed 180/213 channel ids in 353.18s
#   - Processed 200/213 channel ids in 383.94s
# Run equal_weight_cash_hp99999_wait1_pos5 completed in 403.30s
# ------------------------------
# Starting run: equal_weight_cash_hp99999_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 51.02s
#   - Processed 40/213 channel ids in 105.44s
#   - Processed 60/213 channel ids in 150.89s
#   - Processed 80/213 channel ids in 190.44s
#   - Processed 100/213 channel ids in 233.79s
#   - Processed 120/213 channel ids in 268.25s
#   - Processed 140/213 channel ids in 301.66s
#   - Processed 160/213 channel ids in 334.75s
#   - Processed 180/213 channel ids in 366.25s
#   - Processed 200/213 channel ids in 397.95s
# Run equal_weight_cash_hp99999_wait1_pos99999 completed in 417.83s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp21_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 46.28s
#   - Processed 40/213 channel ids in 93.85s
#   - Processed 60/213 channel ids in 135.63s
#   - Processed 80/213 channel ids in 172.23s
#   - Processed 100/213 channel ids in 211.50s
#   - Processed 120/213 channel ids in 244.36s
#   - Processed 140/213 channel ids in 276.43s
#   - Processed 160/213 channel ids in 308.35s
#   - Processed 180/213 channel ids in 339.13s
#   - Processed 200/213 channel ids in 369.95s
# Run equal_weight_3m_tbills_hp21_wait1_pos5 completed in 389.24s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp21_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 46.83s
#   - Processed 40/213 channel ids in 95.41s
#   - Processed 60/213 channel ids in 137.60s
#   - Processed 80/213 channel ids in 174.74s
#   - Processed 100/213 channel ids in 214.32s
#   - Processed 120/213 channel ids in 247.53s
#   - Processed 140/213 channel ids in 279.50s
#   - Processed 160/213 channel ids in 311.26s
#   - Processed 180/213 channel ids in 342.10s
#   - Processed 200/213 channel ids in 372.97s
# Run equal_weight_3m_tbills_hp21_wait1_pos99999 completed in 392.41s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp126_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 46.18s
#   - Processed 40/213 channel ids in 93.49s
#   - Processed 60/213 channel ids in 135.24s
#   - Processed 80/213 channel ids in 171.94s
#   - Processed 100/213 channel ids in 211.36s
#   - Processed 120/213 channel ids in 244.42s
#   - Processed 140/213 channel ids in 276.73s
#   - Processed 160/213 channel ids in 308.60s
#   - Processed 180/213 channel ids in 339.52s
#   - Processed 200/213 channel ids in 370.25s
# Run equal_weight_3m_tbills_hp126_wait1_pos5 completed in 389.69s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp126_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 47.48s
#   - Processed 40/213 channel ids in 96.53s
#   - Processed 60/213 channel ids in 139.20s
#   - Processed 80/213 channel ids in 176.41s
#   - Processed 100/213 channel ids in 216.63s
#   - Processed 120/213 channel ids in 250.13s
#   - Processed 140/213 channel ids in 282.49s
#   - Processed 160/213 channel ids in 314.68s
#   - Processed 180/213 channel ids in 345.73s
#   - Processed 200/213 channel ids in 376.67s
# Run equal_weight_3m_tbills_hp126_wait1_pos99999 completed in 396.02s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp252_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 46.21s
#   - Processed 40/213 channel ids in 93.92s
#   - Processed 60/213 channel ids in 135.54s
#   - Processed 80/213 channel ids in 172.53s
#   - Processed 100/213 channel ids in 212.14s
#   - Processed 120/213 channel ids in 245.70s
#   - Processed 140/213 channel ids in 278.28s
#   - Processed 160/213 channel ids in 310.27s
#   - Processed 180/213 channel ids in 341.25s
#   - Processed 200/213 channel ids in 371.84s
# Run equal_weight_3m_tbills_hp252_wait1_pos5 completed in 391.23s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp252_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 48.56s
#   - Processed 40/213 channel ids in 99.06s
#   - Processed 60/213 channel ids in 142.74s
#   - Processed 80/213 channel ids in 180.98s
#   - Processed 100/213 channel ids in 221.89s
#   - Processed 120/213 channel ids in 255.86s
#   - Processed 140/213 channel ids in 288.35s
#   - Processed 160/213 channel ids in 320.71s
#   - Processed 180/213 channel ids in 351.87s
#   - Processed 200/213 channel ids in 382.91s
# Run equal_weight_3m_tbills_hp252_wait1_pos99999 completed in 402.51s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp99999_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 46.18s
#   - Processed 40/213 channel ids in 98.19s
#   - Processed 60/213 channel ids in 145.46s
#   - Processed 80/213 channel ids in 185.57s
#   - Processed 100/213 channel ids in 228.55s
#   - Processed 120/213 channel ids in 264.86s
#   - Processed 140/213 channel ids in 300.15s
#   - Processed 160/213 channel ids in 335.25s
#   - Processed 180/213 channel ids in 369.04s
#   - Processed 200/213 channel ids in 402.45s
# Run equal_weight_3m_tbills_hp99999_wait1_pos5 completed in 424.31s
# ------------------------------
# Starting run: equal_weight_3m_tbills_hp99999_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 55.61s
#   - Processed 40/213 channel ids in 116.54s
#   - Processed 60/213 channel ids in 166.77s
#   - Processed 80/213 channel ids in 209.71s
#   - Processed 100/213 channel ids in 256.74s
#   - Processed 120/213 channel ids in 294.47s
#   - Processed 140/213 channel ids in 328.68s
#   - Processed 160/213 channel ids in 362.62s
#   - Processed 180/213 channel ids in 395.00s
#   - Processed 200/213 channel ids in 427.22s
# Run equal_weight_3m_tbills_hp99999_wait1_pos99999 completed in 448.18s
# ------------------------------
# Starting run: equal_weight_SPY_hp21_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 48.70s
#   - Processed 40/213 channel ids in 98.56s
#   - Processed 60/213 channel ids in 142.13s
#   - Processed 80/213 channel ids in 180.27s
#   - Processed 100/213 channel ids in 221.69s
#   - Processed 120/213 channel ids in 256.05s
#   - Processed 140/213 channel ids in 288.96s
#   - Processed 160/213 channel ids in 321.59s
#   - Processed 180/213 channel ids in 353.01s
#   - Processed 200/213 channel ids in 384.29s
# Run equal_weight_SPY_hp21_wait1_pos5 completed in 404.05s
# ------------------------------
# Starting run: equal_weight_SPY_hp21_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 48.18s
#   - Processed 40/213 channel ids in 98.32s
#   - Processed 60/213 channel ids in 143.17s
#   - Processed 80/213 channel ids in 181.69s
#   - Processed 100/213 channel ids in 222.90s
#   - Processed 120/213 channel ids in 256.97s
#   - Processed 140/213 channel ids in 290.17s
#   - Processed 160/213 channel ids in 322.70s
#   - Processed 180/213 channel ids in 354.52s
#   - Processed 200/213 channel ids in 385.65s
# Run equal_weight_SPY_hp21_wait1_pos99999 completed in 405.62s
# ------------------------------
# Starting run: equal_weight_SPY_hp126_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 47.45s
#   - Processed 40/213 channel ids in 97.23s
#   - Processed 60/213 channel ids in 140.08s
#   - Processed 80/213 channel ids in 177.79s
#   - Processed 100/213 channel ids in 217.95s
#   - Processed 120/213 channel ids in 252.36s
#   - Processed 140/213 channel ids in 286.40s
#   - Processed 160/213 channel ids in 319.38s
#   - Processed 180/213 channel ids in 351.59s
#   - Processed 200/213 channel ids in 383.80s
# Run equal_weight_SPY_hp126_wait1_pos5 completed in 404.42s
# ------------------------------
# Starting run: equal_weight_SPY_hp126_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 50.34s
#   - Processed 40/213 channel ids in 105.38s
#   - Processed 60/213 channel ids in 153.44s
#   - Processed 80/213 channel ids in 194.82s
#   - Processed 100/213 channel ids in 239.37s
#   - Processed 120/213 channel ids in 276.34s
#   - Processed 140/213 channel ids in 312.04s
#   - Processed 160/213 channel ids in 347.08s
#   - Processed 180/213 channel ids in 381.20s
#   - Processed 200/213 channel ids in 414.65s
# Run equal_weight_SPY_hp126_wait1_pos99999 completed in 435.85s
# ------------------------------
# Starting run: equal_weight_SPY_hp252_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 50.48s
#   - Processed 40/213 channel ids in 100.57s
#   - Processed 60/213 channel ids in 144.31s
#   - Processed 80/213 channel ids in 182.64s
#   - Processed 100/213 channel ids in 224.14s
#   - Processed 120/213 channel ids in 258.62s
#   - Processed 140/213 channel ids in 293.89s
#   - Processed 160/213 channel ids in 330.47s
#   - Processed 180/213 channel ids in 362.65s
#   - Processed 200/213 channel ids in 394.43s
# Run equal_weight_SPY_hp252_wait1_pos5 completed in 414.25s
# Run dir ../data/portfolios/raw/equal_weight_SPY_hp252_wait1_pos99999 already exists. Skipping.
# ------------------------------
# Starting run: equal_weight_SPY_hp99999_wait1_pos5
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 48.15s
#   - Processed 40/213 channel ids in 98.68s
#   - Processed 60/213 channel ids in 141.78s
#   - Processed 80/213 channel ids in 179.57s
#   - Processed 100/213 channel ids in 220.93s
#   - Processed 120/213 channel ids in 255.55s
#   - Processed 140/213 channel ids in 289.45s
#   - Processed 160/213 channel ids in 322.68s
#   - Processed 180/213 channel ids in 354.48s
#   - Processed 200/213 channel ids in 386.53s
# Run equal_weight_SPY_hp99999_wait1_pos5 completed in 406.52s
# ------------------------------
# Starting run: equal_weight_SPY_hp99999_wait1_pos99999
# PortfolioBuilder: Updated settings.
#   - Processed 20/213 channel ids in 53.50s
#   - Processed 40/213 channel ids in 109.97s
#   - Processed 60/213 channel ids in 157.60s
#   - Processed 80/213 channel ids in 198.28s
#   - Processed 100/213 channel ids in 242.67s
#   - Processed 120/213 channel ids in 278.89s
#   - Processed 140/213 channel ids in 313.01s
#   - Processed 160/213 channel ids in 346.64s
#   - Processed 180/213 channel ids in 378.49s
#   - Processed 200/213 channel ids in 410.43s
# Run equal_weight_SPY_hp99999_wait1_pos99999 completed in 430.54s
