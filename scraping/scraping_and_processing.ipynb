# %% [markdown]
# This notebook contains all scraping-related functionality.
#
# The parts of the code which call the ``yt-dlp`` module are all written out in this notebook to be able to conveniently run ``yt-dlp`` via iPython shell commands. Other parts are mostly outsourced to ``scraping_utils.py`` and ``transcript_utils.py``.

# %% [markdown]
# ### Data Gathering and Filtering Process Overview
#
# 1. **Search**
#     - Get search results (i.e. videos) for list of search queries
# 2. **Channel List**
#     - Apply filters to search results
#     - Compile list of channels from filtered search results
# 3. **Channel Video List**
#     - Get (full) list of videos (and shorts) for each channel
#     - Note: Not full video metadata - only ID, title, view count, approximate upload date, duration (if available...)
# 4. **Filtered Video List**
#     - Apply filters to video list
#       - most importantly: upload date (approximately) within timeframe of interest (except for shorts - not available...)
#       - view count threshold, language, etc.
#     - *Potentially: Classify video titles into relevant and irrelevant (some channels might have majority non-finance content)*
# 5. **Video Transcripts and Metadata**
#     - Get full metadata and transcripts for each video
#     - Note: This is the most time-consuming part of the process -> filtering should be done as much as possible before this step
# 6. **Filtered Transcripts and Metadata**
#     - Apply filters which couldn't be applied before (such as exact video upload date & upload date for shorts)
#     - Save final selection of data to 'data' folder
#     - Create an index file for the videos included in the dataset

# %% [markdown]
# ### Step 1: Get search query results

# %%
# scraping setup
from yt_search_lists import queries_stocks, queries_funds, queries_crypto, queries_commodities

active_queries = [(queries_stocks, "stocks"), 
              (queries_funds, "funds"), 
              (queries_crypto, "crypto"), 
              (queries_commodities, "commodities")
              ]

ytsearch_n = 30 # number of search results to return for each query (before any filtering!)

# %%
### search query execution
import time
import os

output_dir = "1_search"
infojson_dir = f"{output_dir}/info_jsons"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
if not os.path.exists(infojson_dir):
    os.makedirs(infojson_dir)


start_time = time.time()

# implementation in loop
for query_list, query_type in active_queries:
    # create files with headers if necessary
    if not os.path.exists(f"{output_dir}/searchresults_{query_type}.csv"):
        with open(f"{output_dir}/searchresults_{query_type}.csv", "w") as f:
            f.write("upload_date;language;duration;uploader_id;channel_name;video_id;title;tags;query\n")
            
    for idx, query in enumerate(query_list):

        query_start_time = time.time()

        query = query.replace(" ", "+") # youtube search uses + instead of spaces
        output_file = f"{output_dir}/searchresults_{query_type}.csv"

        # download query results using yt-dlp
        # !yt-dlp \
        --skip-download \
        --parse-metadata "video::(?P<formats>)" \
        --parse-metadata "video::(?P<automatic_captions>)" \
        --parse-metadata "video::(?P<thumbnails>)" \
        --no-abort-on-error \
        --sleep-requests 1 \
        --write-info-json \
        --quiet \
        --compat-options no-playlist-metafiles \
        --output "infojson:{infojsons_dir}/%(uploader_id)s_%(id)s" \
        --print-to-file "%(upload_date)s;%(language)s;%(duration)s;%(uploader_id)s;%(channel)s;%(id)s;%(title)s;%(tags)s;{query}" {output_file} \
        "ytsearch{ytsearch_n}:{query}"

        # print progress
        t = time.time()
        minutes, seconds = divmod(t - query_start_time, 60) # running time for current query
        print("-"*60)
        print(f"-- Retrieved {ytsearch_n} search results in {minutes} min {round(seconds)} sec for query: '{query}'")
        print(f"-- {idx+1}/{len(query_list)} queries done for query type: {query_type}")
        minutes, seconds = divmod(t - start_time, 60) # total running time
        print(f"-- Total runtime: {minutes} min {round(seconds)} sec.")
# Out:
# ------------------------------------------------------------
# -- Retrieved 30 search results in 163.7499852180481 seconds for query: 'best+stocks+to+buy'
# -- 1/43 queries done for query type:stocks!
# -- Total runtime: 2.0 min 43.749985218048096 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 157.37215304374695 seconds for query: 'top+shares+to+buytop+stocks+to+invest+in'
# -- 2/43 queries done for query type:stocks!
# -- Total runtime: 5.0 min 21.122138261795044 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 156.1470592021942 seconds for query: 'undervalued+stocks'
# -- 3/43 queries done for query type:stocks!
# -- Total runtime: 7.0 min 57.26919746398926 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.1400067806244 seconds for query: 'worst+stocks+to+buy'
# -- 4/43 queries done for query type:stocks!
# -- Total runtime: 10.0 min 30.409204244613647 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 154.75578618049622 seconds for query: 'best+stocks+to+short'
# -- 5/43 queries done for query type:stocks!
# -- Total runtime: 13.0 min 5.164990425109863 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.48256754875183 seconds for query: 'overvalued+stocks'
# -- 6/43 queries done for query type:stocks!
# -- Total runtime: 15.0 min 40.647557973861694 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.91242837905884 seconds for query: 'stock+tips'
# -- 7/43 queries done for query type:stocks!
# -- Total runtime: 18.0 min 16.559986352920532 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 154.9724156856537 seconds for query: 'stock+predictions'
# -- 8/43 queries done for query type:stocks!
# -- Total runtime: 20.0 min 51.53240203857422 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.90493774414062 seconds for query: 'stock+recommendations'
# -- 9/43 queries done for query type:stocks!
# -- Total runtime: 23.0 min 27.43834114074707 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 154.73021864891052 seconds for query: 'which+stock+should+i+buy'
# -- 10/43 queries done for query type:stocks!
# -- Total runtime: 26.0 min 2.1685597896575928 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.81158351898193 seconds for query: 'top+3+stocks'
# -- 11/43 queries done for query type:stocks!
# -- Total runtime: 28.0 min 37.980143308639526 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 156.42619228363037 seconds for query: 'top+10+stocks'
# -- 12/43 queries done for query type:stocks!
# -- Total runtime: 31.0 min 14.406335592269897 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.87526392936707 seconds for query: 'stock+picks+2023'
# -- 13/43 queries done for query type:stocks!
# -- Total runtime: 33.0 min 48.28159952163696 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.5329601764679 seconds for query: 'stock+picks+2022'
# -- 14/43 queries done for query type:stocks!
# -- Total runtime: 36.0 min 23.81455969810486 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 159.96196365356445 seconds for query: 'stock+picks+2021'
# -- 15/43 queries done for query type:stocks!
# -- Total runtime: 39.0 min 3.7765233516693115 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.2648730278015 seconds for query: 'stock+picks+2020'
# -- 16/43 queries done for query type:stocks!
# -- Total runtime: 41.0 min 37.041396379470825 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.41694688796997 seconds for query: 'stock+picks+2019'
# -- 17/43 queries done for query type:stocks!
# -- Total runtime: 44.0 min 10.458343267440796 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 162.47187662124634 seconds for query: 'stock+picks+2018'
# -- 18/43 queries done for query type:stocks!
# -- Total runtime: 46.0 min 52.930219888687134 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 168.7335340976715 seconds for query: 'stock+picks+2017'
# -- 19/43 queries done for query type:stocks!
# -- Total runtime: 49.0 min 41.66375398635864 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.2535481452942 seconds for query: 'best+stocks+january+2022'
# -- 20/43 queries done for query type:stocks!
# -- Total runtime: 52.0 min 16.917302131652832 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.32571649551392 seconds for query: 'best+stocks+february+2021'
# -- 21/43 queries done for query type:stocks!
# -- Total runtime: 54.0 min 50.24301862716675 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 159.02797770500183 seconds for query: 'best+stocks+march+2020'
# -- 22/43 queries done for query type:stocks!
# -- Total runtime: 57.0 min 29.27099633216858 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 157.9545922279358 seconds for query: 'best+stocks+april+2019'
# -- 23/43 queries done for query type:stocks!
# -- Total runtime: 60.0 min 7.22558856010437 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 168.0019338130951 seconds for query: 'best+stocks+may+2018'
# -- 24/43 queries done for query type:stocks!
# -- Total runtime: 62.0 min 55.22752237319946 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 159.79845237731934 seconds for query: 'best+stocks+june+2017'
# -- 25/43 queries done for query type:stocks!
# -- Total runtime: 65.0 min 35.0259747505188 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 163.83693480491638 seconds for query: 'best+stocks+july+2017'
# -- 26/43 queries done for query type:stocks!
# -- Total runtime: 68.0 min 18.86290955543518 sec.
# ------------------------------------------------------------
# WARNING: [youtube] Failed to download m3u8 information: HTTP Error 503: Service Unavailable
# ------------------------------------------------------------
# -- Retrieved 30 search results in 162.0878562927246 seconds for query: 'best+stocks+august+2018'
# -- 27/43 queries done for query type:stocks!
# -- Total runtime: 71.0 min 0.95076584815979 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 156.58734965324402 seconds for query: 'best+stocks+september+2019'
# -- 28/43 queries done for query type:stocks!
# -- Total runtime: 73.0 min 37.53811550140381 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.1039080619812 seconds for query: 'best+stocks+october+2020'
# -- 29/43 queries done for query type:stocks!
# -- Total runtime: 76.0 min 9.64202356338501 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 156.0929229259491 seconds for query: 'best+stocks+november+2021'
# -- 30/43 queries done for query type:stocks!
# -- Total runtime: 78.0 min 45.734946489334106 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 154.71191930770874 seconds for query: 'best+stocks+december+2022'
# -- 31/43 queries done for query type:stocks!
# -- Total runtime: 81.0 min 20.446865797042847 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 151.16566920280457 seconds for query: 'best+dividend+stocks'
# -- 32/43 queries done for query type:stocks!
# -- Total runtime: 83.0 min 51.61253499984741 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.59300589561462 seconds for query: 'best+growth+stocks'
# -- 33/43 queries done for query type:stocks!
# -- Total runtime: 86.0 min 24.205540895462036 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.07092905044556 seconds for query: 'best+value+stocks'
# -- 34/43 queries done for query type:stocks!
# -- Total runtime: 88.0 min 57.27646994590759 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.05790996551514 seconds for query: 'best+tech+stocks'
# -- 35/43 queries done for query type:stocks!
# -- Total runtime: 91.0 min 29.33437991142273 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.03365468978882 seconds for query: 'best+healthcare+stocks'
# -- 36/43 queries done for query type:stocks!
# -- Total runtime: 94.0 min 1.3680346012115479 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.00291061401367 seconds for query: 'best+energy+stocks'
# -- 37/43 queries done for query type:stocks!
# -- Total runtime: 96.0 min 33.37094521522522 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 151.47479248046875 seconds for query: 'best+financial+stocks'
# -- 38/43 queries done for query type:stocks!
# -- Total runtime: 99.0 min 4.84573769569397 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 150.40115904808044 seconds for query: 'best+real+estate+stocks'
# -- 39/43 queries done for query type:stocks!
# -- Total runtime: 101.0 min 35.246896743774414 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 150.01801347732544 seconds for query: 'best+retail+stocks'
# -- 40/43 queries done for query type:stocks!
# -- Total runtime: 104.0 min 5.2649102210998535 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.61751532554626 seconds for query: 'good+european+stocks'
# -- 41/43 queries done for query type:stocks!
# -- Total runtime: 106.0 min 37.88242554664612 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 150.22393035888672 seconds for query: 'good+uk+stocks'
# -- 42/43 queries done for query type:stocks!
# -- Total runtime: 109.0 min 8.106355905532837 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 149.87168884277344 seconds for query: 'good+us+stocks'
# -- 43/43 queries done for query type:stocks!
# -- Total runtime: 111.0 min 37.978044748306274 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.52637648582458 seconds for query: 'best+funds+to+buy'
# -- 1/5 queries done for query type:funds!
# -- Total runtime: 114.0 min 10.50442123413086 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.72347235679626 seconds for query: 'best+etfs+to+buy'
# -- 2/5 queries done for query type:funds!
# -- Total runtime: 116.0 min 44.227893590927124 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 151.75906658172607 seconds for query: 'best+stock+fund'
# -- 3/5 queries done for query type:funds!
# -- Total runtime: 119.0 min 15.986960172653198 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.90751338005066 seconds for query: 'worst+etf'
# -- 4/5 queries done for query type:funds!
# -- Total runtime: 121.0 min 51.89447355270386 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.4053246974945 seconds for query: 'worst+fund'
# -- 5/5 queries done for query type:funds!
# -- Total runtime: 124.0 min 27.299798250198364 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 150.16748428344727 seconds for query: 'best+crypto+to+invest+in'
# -- 1/10 queries done for query type:crypto!
# -- Total runtime: 126.0 min 57.46728253364563 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 150.04735708236694 seconds for query: 'which+crypto+should+i+buy'
# -- 2/10 queries done for query type:crypto!
# -- Total runtime: 129.0 min 27.514639616012573 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.56186628341675 seconds for query: 'worst+crypto+to+buy'
# -- 3/10 queries done for query type:crypto!
# -- Total runtime: 132.0 min 1.0765058994293213 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 148.56803607940674 seconds for query: 'crypto+short'
# -- 4/10 queries done for query type:crypto!
# -- Total runtime: 134.0 min 29.64454197883606 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 148.2601969242096 seconds for query: 'bitcoin+price+prediction'
# -- 5/10 queries done for query type:crypto!
# -- Total runtime: 136.0 min 57.904738903045654 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 148.60818791389465 seconds for query: 'top+3+cryptos'
# -- 6/10 queries done for query type:crypto!
# -- Total runtime: 139.0 min 26.512926816940308 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 150.3958764076233 seconds for query: 'crypto+tips'
# -- 7/10 queries done for query type:crypto!
# -- Total runtime: 141.0 min 56.9088032245636 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 149.1277847290039 seconds for query: 'crypto+picks+2022'
# -- 8/10 queries done for query type:crypto!
# -- Total runtime: 144.0 min 26.036587953567505 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 146.68879628181458 seconds for query: 'crypto+picks+2021'
# -- 9/10 queries done for query type:crypto!
# -- Total runtime: 146.0 min 52.72538423538208 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 148.2894265651703 seconds for query: 'crypto+picks+2020'
# -- 10/10 queries done for query type:crypto!
# -- Total runtime: 149.0 min 21.014810800552368 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 154.2968146800995 seconds for query: 'best+commodity+to+invest+in'
# -- 1/9 queries done for query type:commodities!
# -- Total runtime: 151.0 min 55.311625480651855 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.04340434074402 seconds for query: 'which+commodity+should+i+buy'
# -- 2/9 queries done for query type:commodities!
# -- Total runtime: 154.0 min 27.355029821395874 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 156.7652554512024 seconds for query: 'worst+commodity+to+buy'
# -- 3/9 queries done for query type:commodities!
# -- Total runtime: 157.0 min 4.120285272598267 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 151.66015648841858 seconds for query: 'commodity+short'
# -- 4/9 queries done for query type:commodities!
# -- Total runtime: 159.0 min 35.780441761016846 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 152.60960221290588 seconds for query: 'top+3+commodities'
# -- 5/9 queries done for query type:commodities!
# -- Total runtime: 162.0 min 8.39004397392273 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 153.36359333992004 seconds for query: 'commodity+tips'
# -- 6/9 queries done for query type:commodities!
# -- Total runtime: 164.0 min 41.754597663879395 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 156.77742290496826 seconds for query: 'commodity+picks+2022'
# -- 7/9 queries done for query type:commodities!
# -- Total runtime: 167.0 min 18.532020568847656 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 155.87594604492188 seconds for query: 'commodity+picks+2021'
# -- 8/9 queries done for query type:commodities!
# -- Total runtime: 169.0 min 54.40796661376953 sec.
# ------------------------------------------------------------
# ------------------------------------------------------------
# -- Retrieved 30 search results in 154.24506521224976 seconds for query: 'commodity+picks+2020'
# -- 9/9 queries done for query type:commodities!
# -- Total runtime: 172.0 min 28.653031826019287 sec.
# ------------------------------------------------------------

# %% [markdown]
# ### Step 2: Filter search results and compile unique channel list

# %%
from scraping_utils import load_channel_search_results, filter_search_results
import pandas as pd

### pre-filtering channels

## read in channel search csvs
channel_search_dir = "1_search"
query_types_to_include = ["stocks", "funds", "crypto", "commodities"]

df = load_channel_search_results(channel_search_dir, query_types_to_include)

# apply filters to initial video search results and obtain df of unique channels for which at least one video passes filters

channels = filter_search_results(df, 
                                 query_types_to_include=query_types_to_include, # already defined above
                                 langs_to_include= ["en"], 
                                 min_view_count = 1000,
                                 min_channel_follower_count = 10000, 
                                 max_duration = 45*60 # (sec), to filter out super long-form podcasts etc.
)
# Out:
# fixed line (semicolons in tags): 20220207;en;101;@MonarchNetworth;Monarch Networth;hqHu39Sgzqk;#GemsofMNCL | Stock Picks | 2021;['MNCL', 'Monarch', 'Networth', 'Capital', 'Ltd', 'vaibhav', 'shah', 'mnclgroup.com'];stock+picks+2021
# Could not find file: 1_search/info_jsons/@j.m0ney133_DwQKPtKtW7c.info.json
# channel_follower_count missing in: 1_search/info_jsons/@moneywise1379_hwnnKPPIr0I.info.json
# Could not find file: 1_search/info_jsons/@marketpost.inbystockmarket_82exJU-IMYk.info.json
# Could not find file: 1_search/info_jsons/@LewisHarding.Finance_xxVYLFd3JO8.info.json
# Could not find file: 1_search/info_jsons/@capturn.official_DcVr1LsZqRY.info.json
# ------------------------------------------------------------
# Read in 2008 videos (query categories: ['stocks' 'funds' 'crypto' 'commodities'])
# Missing value counts:
# upload_date                 0
# language                  164
# duration                    1
# uploader_id                 0
# channel_name                0
# video_id                    0
# title                       0
# tags                        0
# query                       0
# query_type                  0
# view_count                588
# channel_follower_count    589
# dtype: int64
# ------------------------------------------------------------
# Applying filters to search results...
# ------------------------------------------------------------
# 2008 initial videos
# 1424 unique videos (before any filters)
# 707 unique channels (before any filters)
#
# 1061 unique videos after language filter
# 530 unique channels after language filter
#
# 1015 unique videos after duration filter
# 501 unique channels after duration filter
#
# 827 unique videos after view count filter
# 405 unique channels after view count filter
#
# 733 unique videos after follower count filter
# 324 unique channels after follower count filter
#
# ------------------------------------------------------------
# Final number of unique channels after filtering: 324

# %%
# rename all files in channel_search/info_jsons 
# previous naming scheme: {uploader_id}_{video_id}.{ext}_info.info.json
# new naming scheme: {uploader_id}_{video_id}.info.json

# note: fixed earlier version of yt-dlp call so this is no longer necessary
from scraping_utils import rename_infojsons

#infojsons_dir = "channel_search/info_jsons"
#rename_infojsons(infojsons_dir)

# %%
# remove news (and other irrelevant) channels 
from yt_search_lists import news_channels, non_relevant_channels # (formerly: other_channels_to_ignore)

print(f"number of channels before dropping any: {len(channels)}")
channels = channels[~channels.uploader_id.isin(news_channels)]
print(f"number of channels after dropping news_channels: {len(channels)}")
channels = channels[~channels.uploader_id.isin(non_relevant_channels)].reset_index(drop=True)
print(f"number of channels after dropping non_relevant_channels: {len(channels)}")

# note: entries have been added to non_relevant_channels after this cell was last run (and filtered out in a later step)
# Out:
# number of channels before dropping any: 324
# number of channels after dropping news_channels: 311
# number of channels after dropping other_channels_to_ignore: 307

# %%
## step 4: save to csv, with index
channel_search_dir = "1_search"
channels.to_csv(f"{channel_search_dir}/filtered_channels.csv", sep=";", header=True, index=True)

# %% [markdown]
# ### Step 3: Get full video lists for channels

# %%
# load from csv, with index col
channel_list_dir = "2_channel_list"
channels = pd.read_csv(f"{channel_list_dir}/filtered_channels.csv", sep=";", header=0, index_col=0)
print(f"number of channels after loading from csv: {len(channels)}")
# Out:
# number of channels after loading from csv: 309

# %%
import time
import os
### get playlist info for channels (video ids, titles, approx. upload dates, etc. of all videos and shorts)

output_dir = "3_channel_video_lists/channel_playlists"
channel_list_dir = "2_channel_list"
start_at_df_idx = 0 # adjust in case a previous run was interrupted

# load channels from csv
channels = pd.read_csv(f"{channel_list_dir}/filtered_channels.csv", sep=";", header=0, index_col=0)

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
skipped_channels = []
start_time = time.time()

channels_to_iterate = channels.iloc[start_at_df_idx:]
#channels_to_iterate = channels[channels['uploader_id'].isin(['@investingforall5118', '@JoelKlattShow'])].reset_index(drop=True)
for idx, row in channels_to_iterate.iterrows():

    channel_start_time = time.time()
    channel_id = row['uploader_id']
    output_file = f"{output_dir}/video_list_{channel_id}.csv"

    # only proceed if file doesn't exist yet
    if not os.path.isfile(output_file):
        with open(output_file, "w") as f:
            f.write("channel_id;video_id;approx_upload_date;duration;yt_video_type;view_count;title\n")

        # get --flat-playlist info for all normal videos and shorts (-> no live streams!)
        for yt_video_type in ['video', 'short']:
            # !yt-dlp \
            --skip-download \
            --no-abort-on-error \
            --sleep-requests 1 \
            --flat-playlist \
            --compat-options no-playlist-metafiles \
            --extractor-args "youtubetab:approximate_date=True" \
            --quiet \
            --print-to-file "{channel_id};%(id)s;%(upload_date)s;%(duration)s;{yt_video_type};%(view_count)s;%(title)s" {output_file} \
            "https://www.youtube.com/{channel_id}/{yt_video_type}s"

        # print progress
        t = time.time()
        print("-"*60)
        minutes, seconds = divmod(t - channel_start_time, 60)
        print(f"-- Retrieved video list for channel {channel_id} in {minutes} min {round(seconds)} sec.")
        print(f"-- {idx+1}/{len(channels_to_iterate)} channels done.")
        minutes, seconds = divmod(t - start_time, 60) # total running time
        print(f"-- Total runtime: {minutes} min {round(seconds)} sec.")

    else:
        print(f"skipping channel {channel_id} (file already exists)")
        skipped_channels.append(channel_id)

print(f"skipped channels: {skipped_channels}")
# Out:
# skipping channel @JoelKlattShow (file already exists)
# skipping channel @investingforall5118 (file already exists)
# skipped channels: ['@JoelKlattShow', '@investingforall5118']

# %%
### cleaning the csvs (see channel_search_utils.fix_channel_playlist_csvs for details)

# we proceed as follows:
    # 1. create new folder for fixed csvs
    # 2. iterate over all csvs in backup folder (read-only!) and write lines (with fixes if necessary) to new csvs in new folder
    # 3. verify new csvs for correctness
    # 4. rename old folder to backup_pre_title_fix and new folder to old folder name

# this cell performs steps 1-3

from scraping_utils import fix_channel_playlist_csvs, load_channel_playlist_csvs, check_channel_playlist_df

old_dir = "3_channel_video_lists/channel_playlists"
new_dir = "3_channel_video_lists/channel_playlists_fixed"

new_dir = old_dir # COMMENT OUT TO ACTUALLY PERFORM FIXES!!!

#faulty_lines = fix_channel_playlist_csvs(old_dir=, new_dir, return_faulty_lines=True)
df = load_channel_playlist_csvs(new_dir)
check_channel_playlist_df(df)
# Out:
# empty file: video_list_@investingforall5118.csv
# empty file: video_list_@JoelKlattShow.csv
# ------------------------------------------------------------
# Read in 414016 videos from 306 channels.
# ------------------------------------------------------------
# data types:
# channel_id                    object
# video_id                      object
# approx_upload_date    datetime64[ns]
# duration                     float64
# yt_video_type                 object
# view_count                   float64
# title                         object
# dtype: object
# ------------------------------------------------------------
# n videos with na values: 2/354703
# n shorts with na values: 59313/59313 (duration and upload date aren't available for shorts)

# %%
# check videos with na values
# these should only be due to issues from youtube's side (e.g. video was deleted)
# (note: apparently there are videos without a viewcount (e.g. m5PM6kDaNrs) or with other weird issues (e.g. 52EWV2rQuZI)
df[df.yt_video_type == 'video'][df[df.yt_video_type == 'video'].isna().any(axis=1)]
# Out:
#             channel_id     video_id approx_upload_date  duration  \
# 256141       @RevZilla  m5PM6kDaNrs         2010-01-27     263.0
# 275536  @SchoolOfTrade  52EWV2rQuZI         2010-01-27       NaN
#
#        yt_video_type  view_count  \
# 256141         video         NaN
# 275536         video         0.0
#
#                                                     title
# 256141  Dainese Hot Weather Mesh Jacket Options -  Por...
# 275536                                  08 27 09SwingHigh

# %%
# check na counts for every column
df.isna().sum()
# Out:
# channel_id                0
# video_id                  0
# approx_upload_date    59313
# duration              59314
# yt_video_type             0
# view_count                1
# title                     0
# dtype: int64

# %%
# step 4: if check looks good, make old folder into backup dir and rename new folder to old folder name

import os

old_dir = "3_channel_video_lists/channel_playlists"
new_dir = "3_channel_video_lists/channel_playlists_fixed"

backup_dir = f"{old_dir}_backup_pre_fix"

if not os.path.exists(new_dir):
    print(f"error: new folder {new_dir} does not exist, please create it first")
elif os.path.exists(backup_dir):
    print(f"error: backup folder {backup_dir} already exists, please delete it first.")
else:
    # rename old folder to backup folder name
    os.rename(old_dir, backup_dir)
    # rename new folder to old folder name
    os.rename(new_dir, old_dir)
    print(f"Successfully renamed folders.")
# Out:
# error: new folder 3_channel_video_lists/channel_playlists_fixed does not exist, please create it first

# %% [markdown]
# ### Step 4: Filter channel video lists for final round of metadata & transcript scraping

# %%
import pandas as pd
from scraping_utils import load_channel_playlist_csvs, filter_channel_playlist_df
# filters (note: we can't filter shorts by upload date!)
df = load_channel_playlist_csvs("3_channel_video_lists/channel_playlists")

df = filter_channel_playlist_df(df, 
                                max_duration = 45*60, # (sec), to filter out super long-form podcasts etc.
                                min_view_count = 10000,
                                min_upload_date = pd.to_datetime("2015-01-01"), # consider approximate dates!
                                max_upload_date = pd.to_datetime("2022-12-31") # consider approximate dates!
)
# Out:
# empty file: video_list_@investingforall5118.csv
# empty file: video_list_@JoelKlattShow.csv
# ------------------------------------------------------------
# Read in 414016 videos from 306 channels.
# ------------------------------------------------------------
# number of videos before any filters: 414016
# number of videos after duration filter: 402866
# number of videos after view count filter: 130924
# number of videos after upload date filter: 86477
# shorts/normal videos: 21828/64649

# %%
# save filtered video list to csv 
df = df.sort_values(by=["channel_id", "approx_upload_date"], ascending=[True, False]).reset_index(drop=True)
df.to_csv("4_filtered_videos/filtered_videos.csv", sep=";", header=True, index=True)

# %% [markdown]
# ### Step 5: Get full metadata and transcripts for each video

# %%
# download transcripts and metadata for remaining videos 
# note: this cell can be stopped and resumed 

import time
import pandas as pd

download_dir = "5_transcripts_and_metadata"
archive_file = f"{download_dir}/downloaded_index.csv"

# read in filtered video list
df = pd.read_csv("4_filtered_videos/filtered_videos.csv", sep=";", header=0, index_col=0)

# get IDs to to download (by checking against already downloaded IDs)
downloaded = pd.read_csv(archive_file, sep=";", header=0, index_col=0)
download_list = df['video_id'].to_list()
archive_list = downloaded['video_id'].to_list()
ids_to_download = [x for x in download_list if x not in archive_list]

print(f"Number of videos already downloaded: {len(archive_list)}")
print(f"Number of videos left to download: {len(ids_to_download)}")
print(f"-"*60)


progress_print_bs = 50 # print progress every x videos
start_time = time.time()
for idx, video_id in enumerate(ids_to_download):
    
    # !yt-dlp \
    --no-abort-on-error \
    --write-auto-sub \
    --write-thumbnail \
    --skip-download \
    --sub-lang en \
    --sub-format ttml \
    --parse-metadata "video::(?P<formats>)" \
    --parse-metadata "video::(?P<automatic_captions>)" \
    --sponsorblock-mark all \
    --write-info-json \
    --output "infojson:{download_dir}/infojsons/%(uploader_id)s_%(id)s" \
    --output "thumbnail:{download_dir}/thumbnails/%(uploader_id)s_%(id)s_thumbnail.%(ext)s" \
    --output "subtitle:{download_dir}/transcripts/%(uploader_id)s_%(id)s_subs.%(ext)s" \
    --print-to-file "%(uploader_id)s;%(id)s" {archive_file} \
    --sleep-requests 0.2 \
    --quiet \
    "https://www.youtube.com/watch?v={video_id}"


    # print progress
    if (idx+1) % progress_print_bs == 0:
        t = time.time()
        minutes, seconds = divmod(t - start_time, 60)
        hours, minutes = divmod(minutes, 60)
        print(f"-- Downloaded {idx+1}/{len(ids_to_download)} IDs in {hours:.0f} h {minutes:.0f} min {seconds:.1f} sec since start.")
# Out:
# Number of videos already downloaded: 60188
# Number of videos left to download: 26289
# ------------------------------------------------------------
# ERROR: [youtube] 7zuW1TBVSF0: Private video. Sign in if you've been granted access to this video
# ERROR: [youtube] 2yB183XtOQg: Private video. Sign in if you've been granted access to this video
# ERROR: [youtube] bs4sKe_WMck: Private video. Sign in if you've been granted access to this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 50/26289 IDs in 0 h 2 min 4.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 100/26289 IDs in 0 h 4 min 15.4 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 150/26289 IDs in 0 h 6 min 34.2 sec since start.
# -- Downloaded 200/26289 IDs in 0 h 9 min 0.0 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 250/26289 IDs in 0 h 11 min 24.5 sec since start.
# -- Downloaded 300/26289 IDs in 0 h 13 min 48.5 sec since start.
# -- Downloaded 350/26289 IDs in 0 h 16 min 14.1 sec since start.
# -- Downloaded 400/26289 IDs in 0 h 18 min 34.9 sec since start.
# -- Downloaded 450/26289 IDs in 0 h 21 min 46.6 sec since start.
# -- Downloaded 500/26289 IDs in 0 h 24 min 28.4 sec since start.
# -- Downloaded 550/26289 IDs in 0 h 27 min 4.1 sec since start.
# -- Downloaded 600/26289 IDs in 0 h 29 min 31.6 sec since start.
# -- Downloaded 650/26289 IDs in 0 h 31 min 58.7 sec since start.
# -- Downloaded 700/26289 IDs in 0 h 34 min 23.0 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 750/26289 IDs in 0 h 36 min 39.8 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 800/26289 IDs in 0 h 39 min 3.0 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 850/26289 IDs in 0 h 41 min 22.3 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 900/26289 IDs in 0 h 43 min 36.1 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 950/26289 IDs in 0 h 45 min 53.5 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 1000/26289 IDs in 0 h 48 min 10.4 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 1050/26289 IDs in 0 h 50 min 33.7 sec since start.
# -- Downloaded 1100/26289 IDs in 0 h 53 min 10.6 sec since start.
# -- Downloaded 1150/26289 IDs in 0 h 55 min 29.7 sec since start.
# -- Downloaded 1200/26289 IDs in 0 h 57 min 57.0 sec since start.
# -- Downloaded 1250/26289 IDs in 1 h 0 min 14.8 sec since start.
# -- Downloaded 1300/26289 IDs in 1 h 2 min 54.2 sec since start.
# -- Downloaded 1350/26289 IDs in 1 h 5 min 55.0 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 1400/26289 IDs in 1 h 9 min 34.1 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 1450/26289 IDs in 1 h 11 min 43.2 sec since start.
# -- Downloaded 1500/26289 IDs in 1 h 13 min 50.7 sec since start.
# -- Downloaded 1550/26289 IDs in 1 h 15 min 53.0 sec since start.
# -- Downloaded 1600/26289 IDs in 1 h 17 min 55.7 sec since start.
# -- Downloaded 1650/26289 IDs in 1 h 20 min 0.8 sec since start.
# -- Downloaded 1700/26289 IDs in 1 h 22 min 6.1 sec since start.
# -- Downloaded 1750/26289 IDs in 1 h 24 min 11.2 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 1800/26289 IDs in 1 h 26 min 16.6 sec since start.
# -- Downloaded 1850/26289 IDs in 1 h 28 min 24.9 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 1900/26289 IDs in 1 h 30 min 30.0 sec since start.
# -- Downloaded 1950/26289 IDs in 1 h 32 min 34.2 sec since start.
# -- Downloaded 2000/26289 IDs in 1 h 34 min 38.6 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 2050/26289 IDs in 1 h 36 min 58.7 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 2100/26289 IDs in 1 h 39 min 25.6 sec since start.
# -- Downloaded 2150/26289 IDs in 1 h 41 min 30.7 sec since start.
# -- Downloaded 2200/26289 IDs in 1 h 43 min 47.9 sec since start.
# -- Downloaded 2250/26289 IDs in 1 h 45 min 59.5 sec since start.
# -- Downloaded 2300/26289 IDs in 1 h 48 min 5.3 sec since start.
# -- Downloaded 2350/26289 IDs in 1 h 50 min 10.8 sec since start.
# -- Downloaded 2400/26289 IDs in 1 h 52 min 18.0 sec since start.
# -- Downloaded 2450/26289 IDs in 1 h 54 min 24.8 sec since start.
# -- Downloaded 2500/26289 IDs in 1 h 56 min 31.3 sec since start.
# -- Downloaded 2550/26289 IDs in 1 h 58 min 39.9 sec since start.
# -- Downloaded 2600/26289 IDs in 2 h 0 min 52.8 sec since start.
# -- Downloaded 2650/26289 IDs in 2 h 2 min 58.7 sec since start.
# -- Downloaded 2700/26289 IDs in 2 h 5 min 6.5 sec since start.
# -- Downloaded 2750/26289 IDs in 2 h 7 min 12.1 sec since start.
# -- Downloaded 2800/26289 IDs in 2 h 9 min 20.1 sec since start.
# WARNING: Unable to download video thumbnail 41: HTTPSConnectionPool(host='i.ytimg.com', port=443): Read timed out. (read timeout=20.0)
# -- Downloaded 2850/26289 IDs in 2 h 11 min 52.8 sec since start.
# -- Downloaded 2900/26289 IDs in 2 h 14 min 3.1 sec since start.
# -- Downloaded 2950/26289 IDs in 2 h 16 min 13.4 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 3000/26289 IDs in 2 h 18 min 28.8 sec since start.
# -- Downloaded 3050/26289 IDs in 2 h 20 min 44.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 3100/26289 IDs in 2 h 23 min 9.3 sec since start.
# -- Downloaded 3150/26289 IDs in 2 h 25 min 25.1 sec since start.
# -- Downloaded 3200/26289 IDs in 2 h 27 min 43.4 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 3250/26289 IDs in 2 h 30 min 2.6 sec since start.
# -- Downloaded 3300/26289 IDs in 2 h 32 min 56.4 sec since start.
# -- Downloaded 3350/26289 IDs in 2 h 36 min 4.5 sec since start.
# -- Downloaded 3400/26289 IDs in 2 h 38 min 13.6 sec since start.
# -- Downloaded 3450/26289 IDs in 2 h 40 min 17.8 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3500/26289 IDs in 2 h 42 min 22.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3550/26289 IDs in 2 h 44 min 26.8 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3600/26289 IDs in 2 h 46 min 36.8 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3650/26289 IDs in 2 h 48 min 40.8 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3700/26289 IDs in 2 h 50 min 48.2 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3750/26289 IDs in 2 h 52 min 54.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3800/26289 IDs in 2 h 54 min 59.6 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 3850/26289 IDs in 2 h 57 min 28.8 sec since start.
# ^C
# -- Downloaded 3900/26289 IDs in 2 h 59 min 56.7 sec since start.
# -- Downloaded 3950/26289 IDs in 3 h 2 min 29.6 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 4000/26289 IDs in 3 h 4 min 57.9 sec since start.
# -- Downloaded 4050/26289 IDs in 3 h 7 min 9.7 sec since start.
# -- Downloaded 4100/26289 IDs in 3 h 9 min 18.9 sec since start.
# -- Downloaded 4150/26289 IDs in 3 h 11 min 30.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 4200/26289 IDs in 3 h 13 min 47.4 sec since start.
# -- Downloaded 4250/26289 IDs in 3 h 15 min 54.5 sec since start.
# -- Downloaded 4300/26289 IDs in 3 h 18 min 22.8 sec since start.
# -- Downloaded 4350/26289 IDs in 3 h 20 min 46.7 sec since start.
# -- Downloaded 4400/26289 IDs in 3 h 23 min 17.6 sec since start.
# -- Downloaded 4450/26289 IDs in 4 h 2 min 28.8 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0)
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0)
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 504: Gateway Time-out. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 504: Gateway Time-out. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0)
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0)
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0)
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0)
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 504: Gateway Time-out. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 504: Gateway Time-out. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway
# -- Downloaded 4500/26289 IDs in 4 h 10 min 12.9 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (3/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTPSConnectionPool(host='sponsor.ajay.app', port=443): Read timed out. (read timeout=20.0). Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway
# -- Downloaded 4550/26289 IDs in 4 h 14 min 37.4 sec since start.
# -- Downloaded 4600/26289 IDs in 4 h 17 min 47.3 sec since start.
# -- Downloaded 4650/26289 IDs in 4 h 21 min 2.1 sec since start.
# -- Downloaded 4700/26289 IDs in 4 h 24 min 21.7 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 4750/26289 IDs in 4 h 27 min 45.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 4800/26289 IDs in 4 h 31 min 7.2 sec since start.
# -- Downloaded 4850/26289 IDs in 4 h 34 min 25.0 sec since start.
# -- Downloaded 4900/26289 IDs in 4 h 37 min 40.0 sec since start.
# -- Downloaded 4950/26289 IDs in 4 h 41 min 10.5 sec since start.
# -- Downloaded 5000/26289 IDs in 4 h 44 min 27.9 sec since start.
# -- Downloaded 5050/26289 IDs in 10 h 31 min 46.8 sec since start.
# -- Downloaded 5100/26289 IDs in 10 h 35 min 34.4 sec since start.
# -- Downloaded 5150/26289 IDs in 10 h 39 min 18.7 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# -- Downloaded 5200/26289 IDs in 10 h 43 min 2.3 sec since start.
# -- Downloaded 5250/26289 IDs in 10 h 46 min 56.5 sec since start.
# -- Downloaded 5300/26289 IDs in 10 h 50 min 54.7 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 5350/26289 IDs in 10 h 54 min 41.8 sec since start.
# -- Downloaded 5400/26289 IDs in 10 h 58 min 34.9 sec since start.
# -- Downloaded 5450/26289 IDs in 11 h 2 min 39.9 sec since start.
# -- Downloaded 5500/26289 IDs in 11 h 7 min 14.9 sec since start.
# -- Downloaded 5550/26289 IDs in 11 h 11 min 51.4 sec since start.
# -- Downloaded 5600/26289 IDs in 11 h 15 min 35.5 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 5650/26289 IDs in 11 h 19 min 21.6 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 5700/26289 IDs in 11 h 23 min 21.6 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 5750/26289 IDs in 11 h 27 min 27.6 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 5800/26289 IDs in 11 h 31 min 20.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 5850/26289 IDs in 11 h 35 min 12.5 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 5900/26289 IDs in 11 h 39 min 13.9 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 5950/26289 IDs in 11 h 43 min 12.7 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6000/26289 IDs in 11 h 47 min 2.8 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6050/26289 IDs in 11 h 50 min 51.2 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# -- Downloaded 6100/26289 IDs in 11 h 54 min 42.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6150/26289 IDs in 11 h 58 min 34.6 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6200/26289 IDs in 12 h 2 min 22.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6250/26289 IDs in 12 h 6 min 15.7 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6300/26289 IDs in 12 h 10 min 13.9 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6350/26289 IDs in 12 h 14 min 12.6 sec since start.
# -- Downloaded 6400/26289 IDs in 12 h 18 min 53.5 sec since start.
# -- Downloaded 6450/26289 IDs in 12 h 23 min 8.7 sec since start.
# -- Downloaded 6500/26289 IDs in 12 h 27 min 7.5 sec since start.
# -- Downloaded 6550/26289 IDs in 12 h 31 min 50.0 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6600/26289 IDs in 12 h 35 min 36.5 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6650/26289 IDs in 12 h 39 min 25.8 sec since start.
# -- Downloaded 6700/26289 IDs in 12 h 43 min 15.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6750/26289 IDs in 12 h 47 min 1.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6800/26289 IDs in 12 h 50 min 48.1 sec since start.
# -- Downloaded 6850/26289 IDs in 12 h 55 min 12.0 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6900/26289 IDs in 12 h 59 min 18.9 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 6950/26289 IDs in 13 h 3 min 3.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 7000/26289 IDs in 13 h 6 min 46.6 sec since start.
# -- Downloaded 7050/26289 IDs in 13 h 10 min 28.9 sec since start.
# ^C
# ^C
# -- Downloaded 7100/26289 IDs in 13 h 14 min 26.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 7150/26289 IDs in 13 h 18 min 12.3 sec since start.
# -- Downloaded 7200/26289 IDs in 13 h 21 min 55.3 sec since start.
# -- Downloaded 7250/26289 IDs in 13 h 25 min 39.1 sec since start.
# -- Downloaded 7300/26289 IDs in 13 h 29 min 28.2 sec since start.
# -- Downloaded 7350/26289 IDs in 13 h 33 min 10.5 sec since start.
# -- Downloaded 7400/26289 IDs in 13 h 37 min 15.0 sec since start.
# -- Downloaded 7450/26289 IDs in 13 h 41 min 19.9 sec since start.
# -- Downloaded 7500/26289 IDs in 13 h 45 min 0.9 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 7550/26289 IDs in 13 h 48 min 57.6 sec since start.
# -- Downloaded 7600/26289 IDs in 13 h 52 min 37.9 sec since start.
# -- Downloaded 7650/26289 IDs in 13 h 56 min 16.5 sec since start.
# -- Downloaded 7700/26289 IDs in 13 h 59 min 58.2 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 7750/26289 IDs in 14 h 3 min 48.8 sec since start.
# -- Downloaded 7800/26289 IDs in 14 h 7 min 57.3 sec since start.
# -- Downloaded 7850/26289 IDs in 14 h 11 min 56.8 sec since start.
# -- Downloaded 7900/26289 IDs in 14 h 15 min 36.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 7950/26289 IDs in 14 h 19 min 18.6 sec since start.
# -- Downloaded 8000/26289 IDs in 14 h 23 min 4.2 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 8050/26289 IDs in 14 h 26 min 54.2 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# ...
# -- Downloaded 20800/26289 IDs in 39 h 56 min 24.5 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# -- Downloaded 20850/26289 IDs in 39 h 59 min 37.0 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# -- Downloaded 20900/26289 IDs in 40 h 2 min 52.7 sec since start.
# ^C
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# -- Downloaded 20950/26289 IDs in 40 h 5 min 48.3 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# -- Downloaded 21000/26289 IDs in 40 h 8 min 44.8 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 21050/26289 IDs in 40 h 12 min 12.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 21100/26289 IDs in 40 h 15 min 3.8 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# -- Downloaded 21150/26289 IDs in 40 h 17 min 55.0 sec since start.
# -- Downloaded 21200/26289 IDs in 40 h 20 min 58.0 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (3/3)...
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# ERROR: Preprocessing: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (2/3)...
# -- Downloaded 21250/26289 IDs in 40 h 24 min 3.1 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# -- Downloaded 21300/26289 IDs in 40 h 27 min 6.6 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# -- Downloaded 21350/26289 IDs in 40 h 30 min 8.9 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (2/3)...
# -- Downloaded 21400/26289 IDs in 40 h 33 min 15.6 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# -- Downloaded 21450/26289 IDs in 40 h 36 min 18.9 sec since start.
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 500: Internal Server Error. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (2/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (1/3)...
# WARNING: Unable to communicate with SponsorBlock API: HTTP Error 502: Bad Gateway. Retrying (2/3)...
# -- Downloaded 21500/26289 IDs in 40 h 39 min 19.6 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# ERROR: Unable to download video subtitles for 'en': HTTP Error 404: Not Found
# -- Downloaded 21550/26289 IDs in 49 h 23 min 1.4 sec since start.
# -- Downloaded 21600/26289 IDs in 49 h 26 min 0.9 sec since start.
# -- Downloaded 21650/26289 IDs in 49 h 29 min 0.4 sec since start.
# -- Downloaded 21700/26289 IDs in 49 h 32 min 9.3 sec since start.
# -- Downloaded 21750/26289 IDs in 49 h 35 min 17.4 sec since start.
# -- Downloaded 21800/26289 IDs in 49 h 38 min 18.6 sec since start.
# -- Downloaded 21850/26289 IDs in 49 h 41 min 28.4 sec since start.
# -- Downloaded 21900/26289 IDs in 49 h 44 min 41.9 sec since start.
# -- Downloaded 21950/26289 IDs in 49 h 47 min 59.9 sec since start.
# -- Downloaded 22000/26289 IDs in 49 h 51 min 12.9 sec since start.
# -- Downloaded 22050/26289 IDs in 49 h 54 min 23.5 sec since start.
# -- Downloaded 22100/26289 IDs in 49 h 57 min 32.7 sec since start.
# -- Downloaded 22150/26289 IDs in 50 h 0 min 46.9 sec since start.
# -- Downloaded 22200/26289 IDs in 50 h 3 min 57.6 sec since start.
# -- Downloaded 22250/26289 IDs in 50 h 7 min 15.6 sec since start.
# -- Downloaded 22300/26289 IDs in 50 h 10 min 40.7 sec since start.
# -- Downloaded 22350/26289 IDs in 50 h 13 min 55.8 sec since start.
# -- Downloaded 22400/26289 IDs in 50 h 17 min 18.1 sec since start.
# -- Downloaded 22450/26289 IDs in 50 h 20 min 33.5 sec since start.
# -- Downloaded 22500/26289 IDs in 50 h 23 min 47.4 sec since start.
# -- Downloaded 22550/26289 IDs in 50 h 27 min 12.3 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 22600/26289 IDs in 50 h 30 min 32.9 sec since start.
# -- Downloaded 22650/26289 IDs in 50 h 33 min 40.5 sec since start.
# -- Downloaded 22700/26289 IDs in 50 h 36 min 59.9 sec since start.
# -- Downloaded 22750/26289 IDs in 50 h 40 min 13.5 sec since start.
# -- Downloaded 22800/26289 IDs in 50 h 43 min 29.2 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 22850/26289 IDs in 50 h 46 min 39.4 sec since start.
# -- Downloaded 22900/26289 IDs in 50 h 49 min 49.3 sec since start.
# -- Downloaded 22950/26289 IDs in 50 h 53 min 8.8 sec since start.
# WARNING: No subtitle format found matching "ttml" for language en, using vtt
# -- Downloaded 23000/26289 IDs in 50 h 56 min 21.0 sec since start.
# -- Downloaded 23050/26289 IDs in 50 h 59 min 33.9 sec since start.
# -- Downloaded 23100/26289 IDs in 51 h 2 min 52.0 sec since start.
# -- Downloaded 23150/26289 IDs in 51 h 6 min 20.0 sec since start.
# -- Downloaded 23200/26289 IDs in 51 h 9 min 40.8 sec since start.
# -- Downloaded 23250/26289 IDs in 51 h 12 min 58.3 sec since start.
# -- Downloaded 23300/26289 IDs in 51 h 16 min 32.1 sec since start.
# -- Downloaded 23350/26289 IDs in 51 h 20 min 3.2 sec since start.
# -- Downloaded 23400/26289 IDs in 51 h 23 min 35.0 sec since start.
# -- Downloaded 23450/26289 IDs in 51 h 26 min 59.6 sec since start.
# -- Downloaded 23500/26289 IDs in 51 h 30 min 31.4 sec since start.
# -- Downloaded 23550/26289 IDs in 51 h 34 min 3.2 sec since start.
# -- Downloaded 23600/26289 IDs in 51 h 37 min 33.4 sec since start.
# -- Downloaded 23650/26289 IDs in 51 h 40 min 59.9 sec since start.
# -- Downloaded 23700/26289 IDs in 51 h 44 min 34.0 sec since start.
# -- Downloaded 23750/26289 IDs in 51 h 48 min 16.5 sec since start.
# -- Downloaded 23800/26289 IDs in 51 h 52 min 0.3 sec since start.
# -- Downloaded 23850/26289 IDs in 51 h 55 min 53.4 sec since start.
# -- Downloaded 23900/26289 IDs in 51 h 59 min 37.9 sec since start.
# -- Downloaded 23950/26289 IDs in 52 h 3 min 17.5 sec since start.
# -- Downloaded 24000/26289 IDs in 52 h 7 min 3.3 sec since start.
# -- Downloaded 24050/26289 IDs in 52 h 11 min 9.8 sec since start.
# -- Downloaded 24100/26289 IDs in 52 h 14 min 54.9 sec since start.
# -- Downloaded 24150/26289 IDs in 52 h 18 min 28.5 sec since start.
# -- Downloaded 24200/26289 IDs in 52 h 22 min 9.8 sec since start.
# -- Downloaded 24250/26289 IDs in 52 h 25 min 56.4 sec since start.
# -- Downloaded 24300/26289 IDs in 52 h 29 min 45.1 sec since start.
# -- Downloaded 24350/26289 IDs in 52 h 34 min 44.2 sec since start.
# -- Downloaded 24400/26289 IDs in 52 h 38 min 44.0 sec since start.
# -- Downloaded 24450/26289 IDs in 52 h 42 min 20.0 sec since start.
# -- Downloaded 24500/26289 IDs in 52 h 47 min 12.3 sec since start.
# -- Downloaded 24550/26289 IDs in 52 h 52 min 31.3 sec since start.
# -- Downloaded 24600/26289 IDs in 52 h 57 min 44.2 sec since start.
# -- Downloaded 24650/26289 IDs in 53 h 2 min 48.8 sec since start.
# -- Downloaded 24700/26289 IDs in 53 h 7 min 59.7 sec since start.
# -- Downloaded 24750/26289 IDs in 53 h 13 min 22.3 sec since start.
# -- Downloaded 24800/26289 IDs in 53 h 18 min 42.3 sec since start.
# WARNING: [youtube] Invalid start time (2146.0 > 2107) for chapter "Monopoly"
# WARNING: [youtube] Invalid start time (2326.0 > 2229) for chapter "Outro"
# -- Downloaded 24850/26289 IDs in 53 h 23 min 56.2 sec since start.
# WARNING: [youtube] Invalid start time (2170.0 > 2117) for chapter "Outro"
# WARNING: [youtube] Invalid start time (2133.0 > 2066) for chapter "Outro"
# -- Downloaded 24900/26289 IDs in 53 h 29 min 4.5 sec since start.
# WARNING: [youtube] Invalid start time (2650.0 > 2645) for chapter "Numbers Game"
# WARNING: [youtube] Invalid start time (2796.0 > 2645) for chapter "Outro"
# -- Downloaded 24950/26289 IDs in 53 h 34 min 18.3 sec since start.
# -- Downloaded 25000/26289 IDs in 53 h 39 min 34.7 sec since start.
# -- Downloaded 25050/26289 IDs in 53 h 45 min 5.3 sec since start.
# WARNING: [youtube] Invalid start time (2322.0 > 2309) for chapter "One vs Many"
# WARNING: [youtube] Invalid start time (2424.0 > 2309) for chapter "Outro"
# -- Downloaded 25100/26289 IDs in 53 h 50 min 48.2 sec since start.
# WARNING: [youtube] Invalid start time (1578.0 > 1481) for chapter "Outro"
# -- Downloaded 25150/26289 IDs in 53 h 56 min 17.9 sec since start.
# WARNING: [youtube] Invalid start time (2473.0 > 2387) for chapter "Outro"
# WARNING: [youtube] Invalid start time (2101.0 > 2061) for chapter "Russ"
# -- Downloaded 25200/26289 IDs in 54 h 1 min 43.8 sec since start.
# WARNING: [youtube] Invalid start time (2121.0 > 2058) for chapter "Outro"
# WARNING: [youtube] Invalid start time (2135.0 > 2023) for chapter "Outro"
# -- Downloaded 25250/26289 IDs in 54 h 7 min 5.2 sec since start.
# WARNING: [youtube] Invalid start time (2101.0 > 1955) for chapter "Outro"
# WARNING: [youtube] Invalid start time (2285.0 > 2266) for chapter "Ticket to Ride"
# WARNING: [youtube] Invalid start time (2284.0 > 2252) for chapter "Daedalus"
# WARNING: [youtube] Invalid start time (2395.0 > 2252) for chapter "Outro"
# -- Downloaded 25300/26289 IDs in 54 h 12 min 41.0 sec since start.
# WARNING: [youtube] Invalid start time (2067.0 > 2011) for chapter "Outro"
# -- Downloaded 25350/26289 IDs in 54 h 18 min 16.0 sec since start.
# -- Downloaded 25400/26289 IDs in 54 h 23 min 45.5 sec since start.
# -- Downloaded 25450/26289 IDs in 54 h 29 min 28.4 sec since start.
# -- Downloaded 25500/26289 IDs in 54 h 35 min 7.7 sec since start.
# -- Downloaded 25550/26289 IDs in 54 h 40 min 8.9 sec since start.
# -- Downloaded 25600/26289 IDs in 54 h 43 min 58.4 sec since start.
# -- Downloaded 25650/26289 IDs in 54 h 47 min 20.6 sec since start.
# WARNING: [youtube] Invalid start time (1659.0 > 1575) for chapter "Outro"
# -- Downloaded 25700/26289 IDs in 54 h 51 min 12.0 sec since start.
# -- Downloaded 25750/26289 IDs in 54 h 54 min 57.0 sec since start.
# WARNING: [youtube] Invalid start time (1839.0 > 1752) for chapter "Outro"
# -- Downloaded 25800/26289 IDs in 54 h 58 min 51.9 sec since start.
# WARNING: [youtube] Invalid start time (1967.0 > 1879) for chapter "Outro"
# -- Downloaded 25850/26289 IDs in 55 h 4 min 12.7 sec since start.
# WARNING: [youtube] Invalid start time (2058.0 > 2045) for chapter "Send General"
# WARNING: [youtube] Invalid start time (2118.0 > 2045) for chapter "Outro"
# WARNING: [youtube] Invalid start time (1712.0 > 1653) for chapter "Outro"
# -- Downloaded 25900/26289 IDs in 55 h 11 min 28.7 sec since start.
# -- Downloaded 25950/26289 IDs in 55 h 19 min 17.1 sec since start.
# WARNING: [youtube] Invalid start time (1920.0 > 1866) for chapter "Outro"
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 26000/26289 IDs in 55 h 23 min 24.5 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 26050/26289 IDs in 55 h 26 min 20.4 sec since start.
# WARNING: Some SponsorBlock segments are from a video of different duration, maybe from an old version of this video
# -- Downloaded 26100/26289 IDs in 55 h 29 min 29.4 sec since start.
# -- Downloaded 26150/26289 IDs in 55 h 32 min 48.2 sec since start.
# -- Downloaded 26200/26289 IDs in 55 h 35 min 51.3 sec since start.
# -- Downloaded 26250/26289 IDs in 55 h 38 min 53.0 sec since start.

# %%
import pandas as pd
downloaded = pd.read_csv("5_transcripts_and_metadata/downloaded_index.csv", sep=";", header=0, index_col=0)
download_list = df['video_id'].to_list()
print(f"Number of videos downloaded: {len(downloaded)}")
# Out:
# Number of videos downloaded: 86474

# %%
### extract, clean and save transcript files into new dir as csvs
import transcript_utils as tu
transcript_dir = "5_transcripts_and_metadata/transcripts"
new_transcript_dir = "5_transcripts_and_metadata/transcripts_csvs"

tu.extract_entire_dir(transcript_dir, new_transcript_dir, clean_filenames=True)
# Out:
# Beginning extraction for 81294 transcript files from 5_transcripts_and_metadata/transcripts to 5_transcripts_and_metadata/transcripts_csvs...
# 8129/81294 files processed.
# 16258/81294 files processed.
# 24387/81294 files processed.
# 32516/81294 files processed.
# 40645/81294 files processed.
# 48774/81294 files processed.
# 56903/81294 files processed.
# 65032/81294 files processed.
# 73161/81294 files processed.
# 81290/81294 files processed.
# ------------------------------------------------------------
# Extraction complete. 81294 files saved to 5_transcripts_and_metadata/transcripts_csvs.

# %% [markdown]
# ### Step 6: Final Filtering Steps
#
# We apply these additional filters:
#
# - Remove videos from channels which are not primarily finance-related.
# - Upload date must lie within our chosen timeframe (now we have the exact upload dates in the infojsons).
# - Remove videos where the automatically recognized language is not English. This avoids two issues:
#   - When Youtube recognizes the wrong language, the auto-translated english transcript will still be available but it will be complete gibberish.
#   - When the "language" field is missing in the info.json, usually no transcript is available. (The reason why it is missing sometimes is not entirely clear. There are cases where a video contains no spoken words, but also cases where the language should be clearly recognizable.)
# - Remove all videos of channels with less than 10 videos in our sample.

# %%
# read in necessary data and drop duplicates (which somehow made their way in the yt dlp archive file)

import pandas as pd
import json

df = pd.read_csv("5_transcripts_and_metadata/downloaded_index.csv", sep=";", header=0)
df = df.drop_duplicates(subset="video_id").reset_index(drop=True)

# %%
# add fields from infojsons (note: can run for a few min, full df with 86k rows and descriptions/tags is around 0.5 GB)
from scraping_utils import add_infojson_fields
fields_from_json = ['title', 'upload_date', 'duration', 'language', 'view_count', 'tags', 'description', 'categories']

df = df.rename(columns={"channel_id": "uploader_id"})

df = add_infojson_fields(df, fields_from_json, "5_transcripts_and_metadata/infojsons")
df.head()
# Out:
# ------------------------------------------------------------
# Adding fields from info jsons to df (nrows: 86133, fields: ['title', 'upload_date', 'duration', 'language', 'view_count', 'tags', 'description', 'categories'])...
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AdamKhoo_ZUbOBj71oFQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AdamKhoo_apNMkE50kcw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AdamKhoo_I9kfljujR20.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AdamKhoo_jtU00txmkPU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AdamKhoo_ldo9EuvJSJc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AkshatZayn_KooB6MqY-jw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AkshatZayn_TW3W0W8PTrc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AkshatZayn_8jf8HYi39W8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AkshatZayn_xMdUDwrrlLQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AkshatZayn_kroV540RFak.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_JPNZCyF1AHE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_h6S22DGzVbM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_4i_l8SG50a0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_b7r3BXm-mT8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_q70EyRSrEgE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_Pr4AxNBa5kc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_w3r25y6qHVs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlesWorldofStocks_hNmIDbAOUAw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_5OeCOKBf3WU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_ZCnTw3Ksq4s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_ACs5eyN2Ax8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_eMc5d-1nSkg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_L-WBWclkTt4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_gzeXmcXdrb8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_N2gQZwqp7bM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_RLOdnchzSXo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_u_zMDLQgFrM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_YmwsLctRjjI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_oJ1WkE4Bl3k.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_6x6v-BsCGiM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexBeckersChannel_a3gpnD_KQCQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexanderLorenzo_CRI-CyDBn-o.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexanderLorenzo__DjxFoAhu9c.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AlexanderLorenzo_zHBkV-Amibg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_e4S1YiwoRvI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_afNL5bU45Fo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_8Ne9Qi_P9F8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_2c2R3--HHS4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_cz0TDiu8qlc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_GBIOGJr7tnU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_f0RjOcGdeu8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_qr3iP6xfvJw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_WVisRdL4QSI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_XMcGHTiUlWs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_Ctfxkcq0cMo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_2pa3ww8UPgI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_EVKTFom3bmw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_NPTxqzs7ZLg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_asQMKd_IqIQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_UimA2Sw8Wz8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_uGVUpLOP71s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_BoHaBIQKIhQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_z9kcMXVUWt0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_tJGWvHI0edU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_EQczKO8VFk8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_fAb3vfwXu-c.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_FSnxg5q-ahg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_R9jmOspdn1M.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_3tfA8uPfCCI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_TdNWBRecreY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_5CDKN-BH1as.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_5imhy4bdEy4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_Jgq1gJXOJtY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_3Iovn1VLBiM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_M4nTXxZmV0U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_4Oob3ENlEcE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_VsEdbQV8sLI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_YuUnhY2BTRw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_v5Nu6v7KrN0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_wTNeN3ojaRg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_sz3ss8RJ3o8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_oBSJSuE_dE4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_XPR1a-wBdKc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_7MHZCEx1eWw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_krQGRdxsrNM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_XzN0pu6Eohg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_itc6WY3MafU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_vRfeFD5hPyw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_xiqobf5Du7s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_irUMc-WUTn8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_K4JEEq4beOk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_d4kLBmKhOeI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_h1mqewVEd3k.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_HBOnlCiIBZo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_mcBAaIPcFf8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AltcoinDaily_8skVsLIGEHg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AmplifyTradingHUB_Ceheyn7lNjc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_tTaIuYhWloE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_OxzUNvL9RaA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_rMvXhS3nQAo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh__txHXuo2ApE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_9doQNYoTUBk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_HOgtlctnrTE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_RPnXGLRqQAk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_aZAa_TEbRjs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_4CYssZDpMRU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_qr0kf41XnJE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_IbTrN5-tobk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_3QBsbNneejw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_W30SA8504oM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh__W6kKuAUUps.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_GZQ1YfAZ3cw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_DO0ABhyXC38.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_o59zOzlF3xM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_zeaVOxBfuJ0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_6x6yM2SqLhA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_DimZ7gn6DWM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_7XlO1shOvP0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_FroxS3PrKY8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_IibCp34AaJo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_bGx28IDpX6Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_9Z6zOearo_g.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_hLyBU-Wqsbo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_-yiTD63Pc5w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AndreiJikh_pL9dRTAqKP4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvesting_uWpiPQcHNos.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_PfK2FIpEqbw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_XHFAzarZyV8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_o9Px_mZf_H8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_23-nVd6ujrg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_xy2xV6f_6X8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_TMk6DZZeKR8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_eKutGCHO7R0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@AverageJoeInvestor_1xZZYQpIzS0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_AlpvBmH7MUk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_adon2rSfCXg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_txsWfD1_8zs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_NSEqC8geX1w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_ZYqFppt77uc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_K9VT-uVQeYk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_ayKi6sy2Se0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_TAezYOXs4iw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_agFFXxKfHA8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_xVzKUXTE3hw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_0yBWmfb17uw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_5Zf5JSIno_E.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_0Ia734sdk9g.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_KkES-HfJdPE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_j5NXwp5o-T8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_Fb2EqQezcKw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_QzWTdBjZzQE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_mceq6iabUnc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_fZUge-7eZHc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_WYODZiPemIU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_WXdvkKs6Icw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_wflCIK3i48Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_u9IN0upCrf4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_wXWVJ3jRcYE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_t154N1IykBc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_hdyCm2GwLhU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_ih7rSILwuIU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_SAKLfsXpiW8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_8A7qz4KsIq0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_kbM4Jgj3ae0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_f_UKHT8pB_Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_sZmGoJ8psNc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BaapofChart_K6UkHJIkeMU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BitcoinHyper_ZjzDmykevDE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_3YQRRgHsCUc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_p_ioIkj0dRs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_ZizNvew7DG0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_ON63dzp67a4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_wlD9YTPYBqE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_pwz3RnyW3js.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_AbSpbR2ioV4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_Je25S_oBz5U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_Ph9nSj1qwwc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_ExIHUPiAqZY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BlueEdgeCrypto_Yun3v1Lo5nk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BrandonTrades_LGjOdVrWCBc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BriansFarmingVideos_7r2MlbOaexE.info.json
# 5000/86133 rows processed
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BriansFarmingVideos_WbLZSD76coI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BriansFarmingVideos_UZBXDGA0HAI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BriansFarmingVideos_NJXLBrGX6W4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BruceWangOfficial_JV6j9Mxij4s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BruceWangOfficial_OEha7ZrzbV8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_geMRn2S2VlE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_xYiFJ4Uuias.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_WsX3ohxDtxc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_KlA4nQZma7E.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_13CBun2YPuE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_aOXjU98TkRk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_r3l5eIB2CBM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_UdvwVYAaWEc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_r7oOWMyUD8M.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_qpIWe-D3s5w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_V71Cv7mjgfI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_-_qGZaG173w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_ACakZ8KjKwU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_J7yLRZae1Gc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_EzqA6eVcQYg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_ED1FCuzaqos.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_T2smR8fE0Ps.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_eNTlo7mOsrs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_ET3by5B03_k.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_TZd0Q3H8fw4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_CqaknTHsV4A.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_JVpd6mLxW4c.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_FK7wQrm7ElE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_JShQsAuOpPk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_eb9mcdxvgq4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_oO5uKB6Zumw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_pw7SvbShLdI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_Yz90Gr3jiZA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_J5xzybYysy8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive__CcR-9O1Urc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_RoLF1g4swSE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_eZD5wJfDVHg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_TISml33tzW8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_Wmf_r2vfQew.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_41VSjDFyeQU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_M3tnvI6IudY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_i7TvKfJlzqQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_F4mNJyHj_7Q.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_T1Ct3fb5BU8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_UsWs1ZG-6EQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_J1qMtPrHoVs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_WsihB7mj9zY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_zIS31BAL-_g.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_V-0jkf70qkQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_YqTh1DQX4E4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_5_qIgPDF6DA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_uV-CUUFPrRY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_jciGmrJMhjI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_ZKOSyTs2kWc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_Dy56cFYAuPw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_VFlUJNN_bgs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_Y3B0wJaGqA4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_oTvAYO8NGyI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BulldogMindsetArchive_La76e-zPe6o.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_u8vkez-QS3Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_UX70nLzbLwo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_3V0kulD9ZyU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_84PYkbcjZcM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_LpHGR1Fq40Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_O1mmTXdORf0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_fWF6mdC0j4Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_gpS_HtWTYT0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_fQ0jyAf-Hyc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_xIJtSjAjhz8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_s7KEIJYeLFo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_8btiiHuYGX8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_omy8KJnFohM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_BWXy6_xdVgY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_pmOPMM9FgKE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_Qy2zF6IRjuQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_AC3q974m3IM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_tiEt1joeR2U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_eQnVjiUL3hY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_CLKO-WL_SOY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision___JiFNtivMA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_Fc70Hbbv9uU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_0FAdwvS8wcI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_vsnGQBGKdqI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_YHFC-rCdJeY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_qzIGvi7Bo5s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_odtbX-KzCkA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_j8s3fH7lgw0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_fTDKL-41IbQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_J3wNjoTEUl4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@BusinessTelevision_znubxWibm1Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_HIN_IK2_fyM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_eoHKYLxdKZU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_SfXrTIoK_x8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_5hnyb78_sMc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_VZZA1S-r27k.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_c1hxT_wCQ5g.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_RJuMJLkn7Qo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_xFc6j59fxlY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_BPDfs5XOkWk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_u6sHSOQJrmQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_Wv7ryxxmMcY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_nSwokmvsYFo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_xhqANOnnNgU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_imM5mfEH8TU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_dRODlLhUJog.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_7pdBME2UEg0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_ZrOg_K6yxx8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_l_RK9mNh9tM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_V47CdOCDo4s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_c280rI1Ojtc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_SjJ8xYRcRaw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_uO8EoK6wUIY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_a3kq0HOUwAc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_gqVqRLqu8vQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_J01OWPompWU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_5oMPZ8Rn1qM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_GrDtV87IW5E.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade__FzLo1BmP4Q.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_0XYB7aiD20c.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_7-2dKzOG1pM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_9OWty0EITXM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_L4M54db41MQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_x5u4d3iLG_0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_PWh12aY2uks.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_Fn-N5Ai1Tec.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_8Bfoz4fTja0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_vZku3oWgbF4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_WeSgUjbnSwE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_D6ZLGDuSog0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_OS93fRtSbU0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_0QV_5UmGU4Q.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_L3BFpRG-P4E.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_nQV__VVZnAg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_0Ja9YGSkqqY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_jLaoW0gBt5s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_ImKDg-DeFoE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_mlXP10OK4Ek.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_r2cVg4FJkyo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_dteWPUwcXGk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_LUAKIWUlBrM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_kLzdyu_muMg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_7bI9h8On1J0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_b5LzMU9h1I8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_eNT_1B6wz_w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_v6I_ivNtzW0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_58cwnypj2Po.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_HB0LlHrbtbQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_x5u7y0bgW88.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_87bLi7jPSXA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_sYM_LxDrm1Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_q3BqEeYG7_U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_QRcguXxFWLo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade__XxpeSbBSl8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_8bXQa24vt40.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_Fi9ORZHzT8A.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_0ePRnbHq1OM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CARachanaRanade_RDQrDGcqda4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_BM7UE5hRmEM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_fhBZqW5gPgI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_IPXjVnHukoE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_c-ND1DXls24.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_9DE0i6dqjFI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_20QT6RfNWPM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_XXY0v4U-HrQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_pdPpBlJHsuw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_VMRWq79Ii9s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CRUXInvestor_gkp4t0IrEtU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@Capitaltrading_OVchdU5fSdw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@Capitaltrading_OgrLe54t1JM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@Capitaltrading_iat8XfyqJ6s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@Capitaltrading_SaGmRqL-B2c.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CarterFarr_pcQ9m-HHoRc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CarterFarr_v89qzBpiqpY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_45KJHy_Flgs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_w2Vqdmnn2vM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_N3KteOme1v0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_Rx14L3TXSWA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_gS6udF73L8c.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_kVFBLm4slxw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_vHZHazQxeq8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_Mz5LIXu7tFo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CharlieChang_0n28qpsUj_Q.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_-EENggINzx0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_KXfs3gdAA3U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_DrElfMdkGss.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_iK09vEG34bU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_SJt1CwAsGcY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_cDWWTLrMfec.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_1VG7IK90jQQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_oZGP_O1sxnw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_257dhRqDWkA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_sZ3w-QGhpNI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_i8tV1b5XaN4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_jPwTqJ7B9r4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisSain1_08L9hOMvQRQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisWillx_l4evOLhsfo4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisWillx_4tNcbcTY9fM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisWillx_l6AJ8V17qgs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisWillx_rOPcdoYLjJw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ChrisWillx_SORTr8SIN00.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_ZJmRGkADYeQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_9NZwiQAye1g.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_0DGClZD5LEM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_ObZWaCEE8DA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_trpeg4Ny1Ho.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_Il9hJnrp-DM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_40CzUd4Dz94.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_6U_n9omeCoo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_-nt1_GsQx-k.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_1EoGevO_s7U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_29rk6k8MHDU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_coihavp4M1Q.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_g9yIkzD02xU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_zN5s7PidpCk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_lp1kFPpHmrs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_nbnCtZEbfeM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_jApBDjioSiw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_6L7fUPHHFFo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_kRy0otMM_jM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_8Uxxk6Xhj7A.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_GkWxdx8wkp4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CleverProgrammer_9U6CIDNjK7Q.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CoinBureau_r61UszUFwNY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CoinBureau_HF7dxD5ncks.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CoinBureau_y4d8XMBVF1A.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CoinBureau_eOjE9RnF8DI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CoinBureau_opfkTb4ndvc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CoinBureau_a_G31MdGIT0.info.json
# 10000/86133 rows processed
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ConorKenny_KK8Fwo-bCN4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ConorKenny_D6Fq-dR8T1M.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ConorKenny_JZxOfFji_is.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ConorKenny_J9LAelfSd9I.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CouchInvestor_jeg-dK9npU0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CouchInvestor_HTIK0THlPvA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoBanterGroup_z69Cia2bR9E.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoBanterGroup_K6DhhP3szJs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoBusy__dPKwi7gWT0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoBusy_B7joI5Kbcyw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_XwdHCthWHss.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_uCX9Orp5mkc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_Nj8iClwolrE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_Kj_MitURGZk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_n66Iz2-1-6Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips__VcdEovm8u8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_V5U-XXD1YR8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_By_EPFKiApo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_rhhu3Uh8iHE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_qM1qAiRcFxU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoTips_3DByAzGO0QU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_Oc31fGM1B08.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_sgSVYEWEjUI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO__hgjN2Oauo8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_Kk7eK7AUVrI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_0SCzNFSH02w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_TY5jm7uxqnA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_Xai0lI9Uw3M.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_Gw3QGMVj4zE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWendyO_KsgJDulG2vg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWorldJosh_gRA54S5OxGs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoWorldJosh_x2Bi3r1eIwU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_tmPMNqrOWcM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_9Uxpjtf_RBY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_8YI_s1qWDjQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_sNnfkbTzqSY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_zn9UcLrYvJ0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_hHKoAKUvUwI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_2YP8wrSpgCA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_x8fRNDlin1g.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_szouJt8px6c.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_9QSRwIOo09s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_3y46sfcwxtE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_-AEdUKOcsHQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CryptoZach_WZzYSnLV1PU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CstewartCFA_Q5LPI6jbzl4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CstewartCFA_D56IiIy0h-I.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@CstewartCFA_v3M94zLtaWk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_C9sfWxh5srg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_7NFH-w3KM1w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_L0aTDHDXhs0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_LgnCP7-D0qM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_59wbw9RtEKk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_dQERHXgN1SM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_ABFKOGv--4Q.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_fZmNWvPEWYY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_vUNbDqzZKsE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_xJmyY5Q0jdw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@DWGALGO_GmVpefoCVRI.info.json
# ...
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_8hIigRzdlGI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_P2FUDJb4MVc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_s8Y9WEh2ZYk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_kWs2IgnXDHA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_YJ9LZ8qkGyc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_ojoEJrsCpPE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_imfznKhEJVA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_IokqCZOtyFY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_H_Nvp9Y26OE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_XOrMw7PJ7P0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_zDjSQk6Y0xE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_-MQz8YJAj0Y.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_ajy8hQQ9FkI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Tmt0rILTaBI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_LcgwbiQJXlQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_tD9Hm-jALdo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_bTZkzQIqbpU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_WG00RsQ2VrM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_wUUBugTSKtE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_UqrGoK-rc6I.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_CigWR8CprhY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_KtOsAmSjtPI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_g51b-EJAues.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_OxpmCG_owog.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_qZPgXml9JkE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_haY2DhDCrJg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_jipqj-X7oLA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_rc3zwbDt6hk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_GazwP2-I2pc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_cwtUWT2MNEs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_F6M67LetynM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Q5f4thSDKmg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_R0spcDmAnoc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_DgWbfuAYayE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_6g_IcXgm9Zw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_UBFc4bkXS28.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_0vQBsvQQO8o.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_efmBBWcQAYo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_EtbodvVtlYI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_cHykx7V5eKc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_T2ORX2t3Vlo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_FzqgpsUENVk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Cs6HO50RofA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_WJQsLgbKoc4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_E7s3WwXA6JA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_JTun6itGnZU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_e3WVngZlZL4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_4zrZshQSwmI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_CNdqmKK3h5g.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_O7ooXql0W6s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower__rsdjQsiHVc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_u2mf_srAid0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_gk3qyvb_lWs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_b81M4QnYf8U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_mTAQNGVPCwA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_9KgIoAWLngQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_mdX9JcUg0ww.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_hpbpqt4bmqU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_IWuBPZ8L0yo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Eeu3okoHcc0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_MVVNgGcRMRo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_9Qio_rGMipE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_q20nTX4idVM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Y21Fx6PXSjE.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_oaIL37Zob10.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_51usWoq8SmY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_UFpYcgLKQ5w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Npp4PVv2CW4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_cTlMEq8iiTQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_cIC9_XAF-n4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_yDx2AOO4yhk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_fETw-idATP8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_5WgvNz4-OAU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_DBMUnG3ApPk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_mb0SPS-lZeQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_qipXXVTFmDs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_rQCLkvJgt7w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_KFjVj8hKXDk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_LJwy7qXWuNI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_BXXOB3QIVwM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_WbqFort-mP4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_NrrVvc-vScU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_L6_Dn3OZg_U.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_t_-5A6Y3bPQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_dXbaOudgxEM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower__kGI1gPqAJc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_J20LRLt7m5s.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_HYnjkuh3EdQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_mp0vs3UmXBo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_1e2R2H7k4_4.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_oJgxOJCeMzI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_vAr-9iBpzwY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_N6nVGcG226w.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Y83X4wKZvro.info.json
# 85000/86133 rows processed
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_KzGXKBsBxDg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_LqYw5xSkhFA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Zuew4-8s2FM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_HYIIjgiNMsc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_ippvLU13bEg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_tSe-eqwCALk.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_DS5U8aEPFEY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_xpIbrNo_EDA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_RetdgZ4WPBI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_8KpYiMri33A.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_WraqE5Gd8uo.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_IsMab9BWNd0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_tkmU47YBChM.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_kK8LHKboc9I.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_pwzPdfSyJyU.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_QFNTwdDwXJY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_TG6aPusrkyI.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_KhGT4nmDOMs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_ugng13NWepw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_gcvoMFnS7G0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_xl-kCF5TZmQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Y9OhTzcTMMY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_t0Czf_KTMZQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_nBesJ_LppKc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Oon3Ek6WSYc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_GakLmJBG7nY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_G24jsVNl25I.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_c0SowhmvxvY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_gmJlatPuBiQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_MSWQTNhu6Fc.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_BrxWuH6PdWY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_jKv-iHIqqzs.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_YCQTrb8GZ60.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_YsZt0Jtr9g0.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_C_B2qrA6vfw.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_RpYtK9euRgA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_dg4-9w-3Yk8.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_NesDC6rgc5k.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_eouU4V2hE0M.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_v4ifad8lpcA.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_-0x8Ni0cZkg.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_Xc2qcnC5NeY.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@thedicetower_hgacoLGipDQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@ytfinance_N8dO7MuOdHQ.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@zedmonopoly_1ThsoYNOP9M.info.json
# field 'language' missing in: 5_transcripts_and_metadata/infojsons/@zedmonopoly_9D_CgbPrl78.info.json
# adding intermediate lists to df...
# postprocessing...
#   uploader_id     video_id                                              title  \
# 0       @2PPD  5MzzziZaNYw  Automate your Trades on Coinbase Pro using thi...
# 1       @2PPD  iW-tdkuMOyQ  Ye's Bank Account Frozen (Another Reason we ne...
# 2       @2PPD  ol2o9VuEbkE  Whats wrong sbf? 💊 Sam Bankman-Fried shaking u...
# 3       @2PPD  CmXeVHaS4LE             Don't be SAM! Sam was a Scam! #ftxhack
# 4       @2PPD  IyUwdMCfcCk                     Kevin O'Leary brags about #FTX
#
#   upload_date  duration language  view_count  \
# 0  2021-10-12     153.0       en     26015.0
# 1  2022-11-23      23.0       en     32710.0
# 2  2022-11-16       7.0       en     49569.0
# 3  2022-11-12      10.0       en     10863.0
# 4  2022-11-12       5.0       en     23578.0
#
#                                                 tags  \
# 0  [coinbase pro trading bot, coinbase pro tradin...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                          description        categories
# 0  Let me show you how this BOT created $211 prof...  [People & Blogs]
# 1  1️⃣ Learn how I (Live Off Crypto)\n2️⃣ Learn h...       [Education]
# 2  This is SBF on Meet the Press a few months ago...       [Education]
# 3  #SamBankman-Fried #cryptonews #ftx\n\n1️⃣ Lear...       [Education]
# 4  1️⃣ Learn how I (Live Off Crypto)\n2️⃣ Learn h...       [Education]

# %%
# load 4_filtered_videos/filtered_videos.csv and merge with df to get yt_video_type column
df_2 = pd.read_csv("4_filtered_videos/filtered_videos.csv", sep=";", header=0, index_col=0)
df_2 = df_2[['video_id', 'yt_video_type']]
df = pd.merge(df, df_2, on="video_id", how="left")
del df_2
# drop duplicates which could have been introduced by merging
df = df.drop_duplicates(subset="video_id").reset_index(drop=True)
df.head()
# Out:
#   uploader_id     video_id                                              title  \
# 0       @2PPD  5MzzziZaNYw  Automate your Trades on Coinbase Pro using thi...
# 1       @2PPD  iW-tdkuMOyQ  Ye's Bank Account Frozen (Another Reason we ne...
# 2       @2PPD  ol2o9VuEbkE  Whats wrong sbf? 💊 Sam Bankman-Fried shaking u...
# 3       @2PPD  CmXeVHaS4LE             Don't be SAM! Sam was a Scam! #ftxhack
# 4       @2PPD  IyUwdMCfcCk                     Kevin O'Leary brags about #FTX
#
#   upload_date  duration language  view_count  \
# 0  2021-10-12     153.0       en     26015.0
# 1  2022-11-23      23.0       en     32710.0
# 2  2022-11-16       7.0       en     49569.0
# 3  2022-11-12      10.0       en     10863.0
# 4  2022-11-12       5.0       en     23578.0
#
#                                                 tags  \
# 0  [coinbase pro trading bot, coinbase pro tradin...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                          description        categories  \
# 0  Let me show you how this BOT created $211 prof...  [People & Blogs]
# 1  1️⃣ Learn how I (Live Off Crypto)\n2️⃣ Learn h...       [Education]
# 2  This is SBF on Meet the Press a few months ago...       [Education]
# 3  #SamBankman-Fried #cryptonews #ftx\n\n1️⃣ Lear...       [Education]
# 4  1️⃣ Learn how I (Live Off Crypto)\n2️⃣ Learn h...       [Education]
#
#   yt_video_type
# 0         video
# 1         short
# 2         short
# 3         short
# 4         short

# %%
# check null values
df.isna().sum()
# Out:
# uploader_id          0
# video_id             0
# title                1
# upload_date          1
# duration             1
# language          5555
# view_count           1
# tags             10295
# description       5024
# categories           3
# yt_video_type        0
# dtype: int64

# %%
# there is a single faulty video with missing data in all fields -> remove it
df = df.dropna(subset=["title"]).reset_index(drop=True)
# check null values again
df.isna().sum()
# Out:
# uploader_id          0
# video_id             0
# title                0
# upload_date          0
# duration             0
# language          5554
# view_count           0
# tags             10294
# description       5023
# categories           2
# yt_video_type        0
# dtype: int64

# %%
# filter upload dates for our timeframe of interest (again, but this time with exact dates available)

start_cutoff = pd.to_datetime("2016-01-01")
end_cutoff = pd.to_datetime("2022-12-31")
print(f"Number of videos before filtering for upload dates: {len(df)}")
df = df[(df['upload_date'] >= start_cutoff) & (df['upload_date'] <= end_cutoff)].reset_index(drop=True)
print(f"Number of videos after filtering for upload dates: {len(df)}")
# Out:
# Number of videos before filtering for upload dates: 86132
# Number of videos after filtering for upload dates: 68242

# %%
# filter out channels determined to be not relevant (i.e. not finance-related) 
# since there are only ~300 channels, manual review is possible (guided by analyzing most common tags and video categories)
from yt_search_lists import non_relevant_channels

print(f"Number of videos before filtering out non-relevant channels: {len(df)}")
df = df[~df.uploader_id.isin(non_relevant_channels)].reset_index(drop=True)
print(f"Number of videos after filtering out non-relevant channels: {len(df)}")
# Out:
# Number of videos before filtering out non-relevant channels: 68242
# Number of videos after filtering out non-relevant channels: 52832

# %%
# count number of videos below/above duration threshold
for mins in [5, 20, 30, 45]:
    print(f"At or below/above {mins} min duration: {len(df[df.duration <= mins*60])}/{len(df[df.duration > mins*60])}")

# no stricter duration filter applied for now, 30+ min videos are not that common
# Out:
# At or below/above 5 min duration: 14401/38431
# At or below/above 20 min duration: 46659/6173
# At or below/above 30 min duration: 51040/1792
# At or below/above 45 min duration: 52832/0

# %%
# language filters

#print(f"Number of videos with no language info: {len(df[df.language.isna()])}")
#print(f"Number of videos with non-english language: {len(df[df.language != 'en'])}")

print(f"Number of videos before filtering for language: {len(df)}")
df = df[df.language == 'en'].reset_index(drop=True)
print(f"Number of videos after filtering for language: {len(df)}")
# Out:
# Number of videos before filtering for language: 52832
# Number of videos after filtering for language: 46108

# %%
# check for any missing transcript files and filter out those videos 
# note: after the language filters there shouldn't really be many missing transcripts
import os

print(f"Number of videos before filtering for missing transcript files: {len(df)}")
missing_transcripts = []
for idx, row in df.iterrows():
    video_id = row['video_id']
    uploader_id = row['uploader_id']
    if not os.path.exists(f"5_transcripts_and_metadata/transcripts_csvs/{uploader_id}_{video_id}.csv"):
        missing_transcripts.append(video_id)
        print(f"missing transcript for video {video_id} from channel {uploader_id}")

df = df[~df.video_id.isin(missing_transcripts)].reset_index(drop=True)
print(f"Number of videos after filtering for missing transcript files: {len(df)}")
# Out:
# Number of videos before filtering for missing transcripts: 46108
# missing transcript for video T_NIXo3q09c from channel @CARachanaRanade
# missing transcript for video R8ZWwkbS6Ww from channel @CARachanaRanade
# Number of videos after filtering for missing transcripts: 46106

# %%
# filter out channels with less than 10 videos in the observation timeframe (these are likely to be very low viewership (only a few videos made it above the threshold) or inactive)
min_vids = 10
print(f"Number of videos before filtering out channels with less than {min_vids} videos: {len(df)}")
df = df.groupby("uploader_id").filter(lambda x: len(x) >= min_vids).reset_index(drop=True)
print(f"Number of videos after filtering out channels with less than {min_vids} videos: {len(df)}")
#"""
# Out:
# Number of videos before filtering out channels with less than 10 videos: 46106
# Number of videos after filtering out channels with less than 10 videos: 45968

# %% [markdown]
# Now that filtering is finished, we save the final_filtered_index to csv, which just contains ``uploader_id`` and ``video_id``.
#
# We also save a csv with selected metadata for each video, which might be useful for a LLM-based classification task later. (A single csv file will be much easier to upload to e.g. Google Colab than all the individual json files.)
# The following will be included:
#
# - video_id
# - uploader_id
# - title
# - description
# - first three tags (comma-separated string)
# -

# %%
# save filtered index
filtered_index_df = df[['uploader_id', 'video_id']]
filtered_index_df.to_csv("6_filtered_videos_final/filtered_index.csv", sep=";", header=True, index=False)

# %%
# create filtered metadata df 
filtered_metadata_df = df.loc[:, ['uploader_id', 'video_id', 'upload_date', 'yt_video_type', 'view_count', 'duration', 'language', 'title', 'description', 'categories', 'tags']]
# rename categories column
filtered_metadata_df = filtered_metadata_df.rename(columns={"categories": "yt_auto_categories"})
# first three (or fewer) tags column - stored as string for later use in prompts
def first_three_tags(tags):
    if not tags:
        return ""
    else:
        # tags should already be cleaned of separators/commas
        return ", ".join([tag for tag in tags[:3]])
filtered_metadata_df['first_three_tags'] = filtered_metadata_df['tags'].apply(first_three_tags)

# save to csv
filtered_metadata_df.to_csv("6_filtered_videos_final/filtered_metadata.csv", sep=";", header=True, index=False)

# %%
# test whether the loaded metadata df is the same as previously saved df (do weird description characters mess up csv file?)

# handle loading of lists from csv with ast.literal_eval()
import ast
def load_list(x):
    return ast.literal_eval(x) if x else None
loaded_df = pd.read_csv("6_filtered_videos_final/filtered_metadata.csv", sep=";", header=0, converters={"tags": load_list, 
                                                                                                        "yt_auto_categories": load_list})

if not loaded_df.equals(filtered_metadata_df):
    # show differences (only empty strings vs NaNs in the first_three_tags column should show up)
    diff = loaded_df.compare(filtered_metadata_df)
    print(f"Discrepancies found in the following columns: {diff.columns.levels[0][0]}")
    print(diff)
# Out:
# Discrepancies found in the following columns: first_three_tags
#       first_three_tags
#                   self other
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# ...                ...   ...
# 45601              NaN
# 45602              NaN
# 45603              NaN
# 45604              NaN
# 45967              NaN
#
# [4752 rows x 2 columns]

# %%
# finally, also save a version of the index which is sorted by average channel video view count, and videos of a channel are sorted by view count descending.

# load filtered index

filtered_index_sorted = df[['uploader_id', 'video_id', 'view_count', 'yt_video_type']]

# create a new variable 'channel_avg_view_count'
filtered_index_sorted['channel_avg_view_count'] = filtered_index_sorted.groupby('uploader_id')['view_count'].transform('mean')
# sort
filtered_index_sorted = filtered_index_sorted.sort_values(by=['channel_avg_view_count', 'view_count'], ascending=[False, False]).reset_index(drop=True)
# save
filtered_index_sorted.to_csv("6_filtered_videos_final/filtered_index_sorted_avg_channel_views.csv", sep=";", header=True, index=False)
# Out:
# C:\Users\janja\AppData\Local\Temp\ipykernel_23524\2064591107.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_index_sorted['channel_avg_view_count'] = filtered_index_sorted.groupby('uploader_id')['view_count'].transform('mean')

# %% [markdown]
# Below: Code for exploration of categories, tags, etc. which helped to define the irrelevant channel list. Reload the dataframe from the start of this section before continuing.

# %%
# get value counts for different categories
n_vids_by_cat = df['categories'].apply(lambda x: None if not x else x[0]).value_counts()

# add number of channels as second column
cat_df = pd.DataFrame(n_vids_by_cat).reset_index()
cat_df.columns = ['category', 'n_videos']
cat_df['n_channels'] = cat_df['category'].apply(lambda x: len(df[df['categories'].apply(lambda y: None if not y else y[0]) == x]['uploader_id'].unique()))
cat_df = cat_df.sort_values(by="n_videos", ascending=False).reset_index(drop=True)
cat_df
# Out:
#                  category  n_videos  n_channels
# 0               Education     30223         190
# 1          People & Blogs     13460         105
# 2    Science & Technology      3775          20
# 3           Entertainment      3102          64
# 4         News & Politics      2308          29
# 5           Howto & Style      2150          38
# 6                  Gaming       460           8
# 7                  Comedy        59           9
# 8        Autos & Vehicles        51          10
# 9                  Sports        38           4
# 10       Film & Animation        19           9
# 11                  Music        15           2
# 12        Travel & Events         9           7
# 13  Nonprofits & Activism         2           2

# %%
# for each category, get the top 10 channels by percentage of videos in that category

# get categories
categories = df['categories'].apply(lambda x: None if not x else x[0]).value_counts().index.to_list()

# get top 10 channels by percentage of videos in each category
top_channels = {}
for category in categories:
    top_channels[category] = df[df['categories'].apply(lambda x: None if not x else x[0]) == category]['uploader_id'].value_counts(normalize=True).head(10)

print(top_channels)
# Out:
# {'Education': uploader_id
# @MeetKevin                 0.057969
# @GrantCardone              0.052940
# @FinancialEducation        0.038778
# @VALUETAINMENT             0.037885
# @GaryVeeVideoExperience    0.037488
# @RickyGutierrezz           0.035900
# @StockMoe                  0.029448
# @DiscoverCrypto_           0.026867
# @MoneyPurse                0.026139
# @GrahamStephan             0.024352
# Name: proportion, dtype: float64, 'People & Blogs': uploader_id
# @TheRamseyShow            0.345394
# @garyvee                  0.105201
# @Incomeparent             0.062481
# @Thetradingfraternity     0.044799
# @MoneyGuyShow             0.040416
# @TimothySykesTrader       0.029569
# @josephhogue              0.029495
# @investingbasicsyt        0.023923
# @BulldogMindsetArchive    0.023031
# @AkshatZayn               0.022214
# Name: proportion, dtype: float64, 'Science & Technology': uploader_id
# @AltcoinDaily               0.303311
# @TheCryptoLark              0.284768
# @DiscoverCrypto_            0.217483
# @CryptoBusy                 0.060662
# @NuggetsNews                0.054040
# @TickerSymbolYOU            0.028874
# @ConorKenny                 0.018808
# @craigneidel                0.015629
# @enterprisemanagement360    0.005298
# @aliabdaal                  0.002914
# Name: proportion, dtype: float64, 'Entertainment': uploader_id
# @ChrisSain1               0.231464
# @CryptoZach               0.110251
# @RyanPineda               0.083817
# @JosephCarlsonShow        0.065764
# @ffreedomapptelugu        0.056093
# @BulldogMindsetArchive    0.052547
# @CryptoWendyO             0.048678
# @BruceWangOfficial        0.046422
# @RealVisionFinance        0.034816
# @MarenAltman              0.033527
# Name: proportion, dtype: float64, 'News & Politics': uploader_id
# @BusinessTelevision    0.298960
# @RealVisionFinance     0.204073
# @MeetKevin             0.104853
# @TheJayMartinShow      0.093588
# @MotleyFool            0.059359
# @TheStreet             0.049827
# @FinancialEducation    0.029463
# @IGcom                 0.021231
# @ytfinance             0.020797
# @DividendBull          0.020797
# Name: proportion, dtype: float64, 'Howto & Style': uploader_id
# @RisaDoesMakeup          0.248372
# @ZipTrader               0.188372
# @HighLifeWorkout         0.137674
# @theRahulM               0.077674
# @AverageJoeInvestor      0.072558
# @TheCleverMillionaire    0.046977
# @TobyMathis              0.034419
# @TheHumblePenny          0.022791
# @BlueEdgeCrypto          0.021395
# @cryptorenegade          0.019070
# Name: proportion, dtype: float64, 'Gaming': uploader_id
# @TimProVision            0.886957
# @VirtualBacon            0.056522
# @ToriTrades              0.032609
# @InfinityAlgo            0.010870
# @ConorKenny              0.006522
# @TheClashOfTheClans      0.002174
# @Thetradingfraternity    0.002174
# @VALUETAINMENT           0.002174
# Name: proportion, dtype: float64, 'Comedy': uploader_id
# @GrantCardone              0.508475
# @Thetradingfraternity      0.203390
# @CARachanaRanade           0.101695
# @MyFirstMillionPod         0.067797
# @FutureForecastingGroup    0.033898
# @Jungernaut                0.033898
# @FinancialEducation        0.016949
# @GaryVeeVideoExperience    0.016949
# @RickyGutierrezz           0.016949
# Name: proportion, dtype: float64, 'Autos & Vehicles': uploader_id
# @tamiztrader             0.509804
# @FinancialEducation      0.176471
# @TheRamseyShow           0.156863
# @Thetradingfraternity    0.039216
# @CharlieChang            0.019608
# @TheCleverMillionaire    0.019608
# @TheStreet               0.019608
# @craigneidel             0.019608
# @morecryptoonline        0.019608
# @theRahulM               0.019608
# Name: proportion, dtype: float64, 'Sports': uploader_id
# @HighLifeWorkout    0.421053
# @KyleMillis         0.394737
# @Finding_Finance    0.157895
# @ConorKenny         0.026316
# Name: proportion, dtype: float64, 'Film & Animation': uploader_id
# @IndependentInvestor    0.263158
# @SheldonEvansx          0.157895
# @BlueEdgeCrypto         0.105263
# @TheCryptoLark          0.105263
# @craigneidel            0.105263
# @zedmonopoly            0.105263
# @Bankless               0.052632
# @IFGuru                 0.052632
# @thecooperacademy       0.052632
# Name: proportion, dtype: float64, 'Music': uploader_id
# @aliabdaal          0.933333
# @CARachanaRanade    0.066667
# Name: proportion, dtype: float64, 'Travel & Events': uploader_id
# @RICHTVLIVE           0.222222
# @RyanScribner         0.222222
# @ConorKenny           0.111111
# @JerryRomineStocks    0.111111
# @aliabdaal            0.111111
# @craigneidel          0.111111
# @theRahulM            0.111111
# Name: proportion, dtype: float64, 'Nonprofits & Activism': uploader_id
# @ChrisSain1      0.5
# @GrantCardone    0.5
# Name: proportion, dtype: float64}

# %%
# get top 10 uploader ids for each category
top_10_per_category = df['categories'].apply(lambda x: None if not x else x[0]).value_counts().head(10)
for cat in top_10_per_category.index:
    print(f"Top 10 uploaders for category {cat}:")
    print(df[df['categories'].apply(lambda x: None if not x else x[0]) == cat]['uploader_id'].value_counts().head(10))
    print("\n")
# Out:
# Top 10 uploaders for category Education:
# uploader_id
# @GrantCardone              1918
# @MeetKevin                 1752
# @TheMathSorcerer           1475
# @VALUETAINMENT             1469
# @FinancialEducation        1183
# @GaryVeeVideoExperience    1174
# @MoneyPurse                1116
# @RickyGutierrezz           1115
# @StockMoe                   890
# @DiscoverCrypto_            812
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category People & Blogs:
# uploader_id
# @TheRamseyShow           5393
# @garyvee                 1735
# @Incomeparent             929
# @MoneyGuyShow             813
# @ChrisWillx               794
# @DWGALGO                  735
# @BriansFarmingVideos      642
# @Thetradingfraternity     617
# @MarenAltman              539
# @TimothySykesTrader       491
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category Entertainment:
# uploader_id
# @discovery            2745
# @ChrisSain1            718
# @ffreedomapptelugu     404
# @jackneel              400
# @CryptoZach            385
# @garyvee               350
# @coinbureauclips       328
# @RyanPineda            289
# @HenokCrypto           245
# @JosephCarlsonShow     204
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category Gaming:
# uploader_id
# @thedicetower            4761
# @TimProVision             570
# @proguidesapex            259
# @lburi                    107
# @ToriTrades               105
# @InfinityAlgo              81
# @VirtualBacon              26
# @ConorKenny                 3
# @TheClashOfTheClans         1
# @Thetradingfraternity       1
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category Howto & Style:
# uploader_id
# @TheMicheleWang          998
# @sophdoeslife            847
# @HighLifeWorkout         706
# @RisaDoesMakeup          576
# @ZipTrader               405
# @LaurenMaeBeauty         378
# @howtomen                352
# @theRahulM               167
# @AverageJoeInvestor      156
# @TheCleverMillionaire    101
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category Science & Technology:
# uploader_id
# @AltcoinDaily               1227
# @TheCryptoLark              1147
# @DiscoverCrypto_            1023
# @CryptoBusy                  229
# @NuggetsNews                 204
# @TickerSymbolYOU             109
# @oggiai                       76
# @ConorKenny                   71
# @craigneidel                  59
# @enterprisemanagement360      34
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category Autos & Vehicles:
# uploader_id
# @RevZilla                3043
# @discovery                159
# @TheRamseyShow             28
# @tamiztrader               26
# @FinancialEducation         9
# @Thetradingfraternity       2
# @CharlieChang               1
# @TheCleverMillionaire       1
# @TheStreet                  1
# @craigneidel                1
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category News & Politics:
# uploader_id
# @BusinessTelevision    696
# @RealVisionFinance     484
# @MeetKevin             243
# @TheJayMartinShow      232
# @TheStreet             177
# @MotleyFool            153
# @FinancialEducation     68
# @IGcom                  55
# @etfguide               49
# @ytfinance              48
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category Pets & Animals:
# uploader_id
# @discovery    116
# Name: count, dtype: int64
#
#
# Top 10 uploaders for category Film & Animation:
# uploader_id
# @TheMicheleWang         50
# @IndependentInvestor     5
# @SheldonEvansx           3
# @BlueEdgeCrypto          2
# @TheCryptoLark           2
# @craigneidel             2
# @zedmonopoly             2
# @Bankless                1
# @BriansFarmingVideos     1
# @IFGuru                  1
# Name: count, dtype: int64

# %%
# category value counts for certain channels
uploader_id = "@thedicetower"
df[df.uploader_id == uploader_id]['categories'].apply(lambda x: None if not x else x[0]).value_counts()
# Out:
# categories
# Gaming           4761
# Entertainment       1
# Name: count, dtype: int64

# %%
# check median and average number of tags
df['num_tags'] = df['tags'].apply(lambda x: 0 if not x else len(x))
print(f"median number of tags: {df['num_tags'].median()}")
print(f"average number of tags: {df['num_tags'].mean()}")
print(f"max number of tags: {df['num_tags'].max()}")
# Out:
# median number of tags: 17.0
# average number of tags: 16.51677057573752
# max number of tags: 80

# %%
keywords = ["stocks", "investing"]
print(f"given tag list: {keywords}")
print(f"n vids including at least one of the tags: {df['tags'].apply(lambda x: False if not x else any([kw in x for kw in keywords])).sum()}")
print(f"n vids including all of the tags: {df['tags'].apply(lambda x: False if not x else all([kw in x for kw in keywords])).sum()}")
# Out:
# given tag list: ['stocks', 'investing']
# n vids including at least one of the tags: 10187
# n vids including all of the tags: 3541

# %%
# check for most common tags
taglists = df['tags'].apply(lambda x: [] if not x else x).to_list()
tags = [tag for taglist in taglists for tag in taglist]
from collections import Counter
tag_counts = Counter(tags)
tag_counts.most_common(20)
# Out:
# [('stock market', 8476),
#  ('crypto', 7491),
#  ('review', 7412),
#  ('investing', 7174),
#  ('money', 6642),
#  ('stocks', 6554),
#  ('real estate', 5811),
#  ('cryptocurrency', 5730),
#  ('how to make money', 5431),
#  ('bitcoin', 5390),
#  ('dave ramsey', 4853),
#  ('dice tower', 4752),
#  ('game', 4751),
#  ('board game', 4745),
#  ('dice', 4736),
#  ('vasel', 4731),
#  ('tom vasel', 4719),
#  ('credit card', 4714),
#  ('catan', 4703),
#  ('the dave ramsey show', 4486)]

# %%
from collections import Counter

# get uploader ids ordered by number of videos in dataset
counts_df = pd.DataFrame(df['uploader_id'].value_counts()).reset_index()
# add most common category and tags for each uploader
counts_df['most_common_category'] = None
counts_df['most_common_tag#1'] = None
counts_df['most_common_tag#2'] = None
counts_df['most_common_tag#3'] = None

for idx, row in counts_df.iterrows():
    uid = row['uploader_id']
    # get category list for uploader
    catlists = df[df['uploader_id'] == uid]['categories'].apply(lambda x: [] if not x else x)
    cats = [cat for catlist in catlists for cat in catlist]
    # get most common category
    counts_df.at[idx, 'most_common_category'] = max(set(cats), key=cats.count)

    # get tag list for uploader
    taglists = df[df['uploader_id'] == uid]['tags'].apply(lambda x: [] if not x else x)
    tags = [tag for taglist in taglists for tag in taglist]
    # get top 3 tags
    tags = [tag for tag, count in Counter(tags).most_common(3)]
    # get most common tags
    counts_df.at[idx, 'most_common_tag#1'] = tags[0] if tags else None
    counts_df.at[idx, 'most_common_tag#2'] = tags[1] if tags and len(tags) > 1 else None
    counts_df.at[idx, 'most_common_tag#3'] = tags[2] if tags and len(tags) > 2 else None

# %%
counts_df

# %%
# view results
#counts_df[:50]
#counts_df[50:100]
#counts_df[100:150]
#counts_df[150:200]
#counts_df[200:250]
counts_df[250:]
